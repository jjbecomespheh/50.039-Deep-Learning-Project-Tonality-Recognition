# %% [markdown]
# # CNN LSTM Model
#
# 50.039 Theory and Practice of Deep Learning Project

# %%
# !pip install torchinfo

# %%
import pandas as pd
import numpy as np
import os
import librosa
import librosa.display
import seaborn as sn
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from Preprocessor import *
from Constants import *
from MelTrainHelper import Train_Helper

from tqdm import tqdm
from torchinfo import summary
from IPython.display import Audio
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
# Out:
# /opt/conda/lib/python3.6/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#Convert Dataset into Pandas Dataframe
Tess = "./TESS"

tess_directory_list = os.listdir(Tess)
preprocessor = DataPreprocessor()   
file_paths, labels = preprocessor.get_file_paths_and_labels(Tess)

EMOTIONS= {'neutral':0,'happy':1, 'sad':2, 'angry':3, 'fear':4, 'disgust':5, 'ps':6}
encoded_labels = [EMOTIONS[label] for label in labels]
emotion_df = pd.DataFrame(labels, columns=['Emotions'])
print("ALL EMOTIONS:", set(labels))

path_df = pd.DataFrame(file_paths, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
# Out:
# ALL EMOTIONS: {'angry', 'ps', 'disgust', 'neutral', 'happy', 'fear', 'sad'}
#   Emotions                              Path
# 0      sad   ./TESS/YAF_sad/YAF_wife_sad.wav
# 1      sad   ./TESS/YAF_sad/YAF_hate_sad.wav
# 2      sad  ./TESS/YAF_sad/YAF_phone_sad.wav
# 3      sad   ./TESS/YAF_sad/YAF_week_sad.wav
# 4      sad   ./TESS/YAF_sad/YAF_raid_sad.wav

# %% [markdown]
# # Dataset

# %%
# #Convert Dataset into Pandas Dataframe
# RAVDESS = "./RAVDESS"

# preprocessor = DataPreprocessor()   
# file_paths, labels = preprocessor.get_file_paths_and_labels_RAVDESS(RAVDESS)

# CREMA_D_EMOTION_ENCODING = {'FEA':0,'DIS':1, 'HAP':2, 'SAD':3, 'ANG':4, 'NEU':5}
# encoded_labels = [CREMA_D_EMOTION_ENCODING[label] for label in labels]
# emotion_df = pd.DataFrame(labels, columns=['Emotions'])
# print("ALL EMOTIONS:", set(labels))

# path_df = pd.DataFrame(file_paths, columns=['Path'])
# CREMA_D_df = pd.concat([emotion_df, path_df], axis=1)
# CREMA_D_df.head()

# %%
# #Convert Dataset into Pandas Dataframe
# CREMA_D = "./CREMA_D"

# preprocessor = DataPreprocessor()   
# file_paths, labels = preprocessor.get_file_paths_and_labels_CREMA(CREMA_D)

# CREMA_D_EMOTION_ENCODING = {'FEA':0,'DIS':1, 'HAP':2, 'SAD':3, 'ANG':4, 'NEU':5}
# encoded_labels = [CREMA_D_EMOTION_ENCODING[label] for label in labels]
# emotion_df = pd.DataFrame(labels, columns=['Emotions'])
# print("ALL EMOTIONS:", set(labels))

# path_df = pd.DataFrame(file_paths, columns=['Path'])
# CREMA_D_df = pd.concat([emotion_df, path_df], axis=1)
# CREMA_D_df.head()

# %% [markdown]
# # Data Preprocessing

# %%
# #Extracting mel spectrograms from Dataset
# signals = preprocessor.extract_audio_signals(Tess_df['Path'])
# #signals = preprocessor.extract_audio_signals(Tess_df['Path'])
# mel_spectograms = preprocessor.extract_mel_spectograms(signals)

# %%
# # Rune only if the converted mel_spectrograms are not saved into numpy array yet
# with open('crema_mel_spec_all.npy', 'wb') as f:
#     np.save(f, mel_spectograms)

# %%
with open('mel_spec_all.npy', 'rb') as f:
    mel_spectograms = np.load(f)

# %%
#Spliting extracted mel spectrogram data into training, testing and validation set
X_train, X_val, X_test, Y_train, Y_val, Y_test = preprocessor.train_val_test_split(mel_spectograms, encoded_labels)
#Scaling and reshape Data for training
X_train = preprocessor.reshape_scale_data(X_train)
X_test = preprocessor.reshape_scale_data(X_test)
X_val = preprocessor.reshape_scale_data(X_val)

# %% [markdown]
# # Create the model

# %%
class SEQUENTIAL_CNN_LSTM(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        hidden_size = 128
        
        conv2d_1 = nn.Conv2d(in_channels=1, out_channels=16, stride=1, padding=1, kernel_size=3)
        conv2d_2 = nn.Conv2d(in_channels=16, out_channels=32, stride=1, padding=1, kernel_size=3)
        conv2d_3 = nn.Conv2d(in_channels=32, out_channels=64, stride=1, padding=1, kernel_size=3)
        conv2d_4 = nn.Conv2d(in_channels=64, out_channels=64, stride=1, padding=1, kernel_size=3)
        relu = nn.ReLU()
        maxPool2_2 = nn.MaxPool2d(kernel_size=2, stride=2)
        maxPool4_4 = nn.MaxPool2d(kernel_size=4, stride=2)
        dropOut = nn.Dropout(p=0.3)
        batchNorm16 = nn.BatchNorm2d(16)
        batchNorm32 = nn.BatchNorm2d(32)
        batchNorm64 = nn.BatchNorm2d(64)
        
        #Convolution Block
        self.conv2Dblock = nn.Sequential(conv2d_1, batchNorm16, relu, maxPool2_2, dropOut,
                                         conv2d_2, batchNorm32, relu, maxPool4_4, dropOut,
                                         conv2d_3, batchNorm64, relu, maxPool4_4, dropOut,
                                         conv2d_4, batchNorm64, relu, maxPool4_4, dropOut)
        #LSTM Block
        hidden_size = 64
        self.lstm = nn.LSTM(input_size=198,
                            hidden_size=hidden_size,
                            bidirectional=False, 
                            batch_first=True) 
        self.dropout_lstm = nn.Dropout(p=0.3)
        self.out_linear = nn.Linear(hidden_size,num_emotions)
    def forward(self,x):
        conv_out = self.conv2Dblock(x)
        conv_out = torch.flatten(conv_out, start_dim=2)
        lstm_out, (h,c) = self.lstm(conv_eout)
        lstm_out = self.dropout_lstm(lstm_out)
        lstm_output = lstm_out[:,-1,:] 
        output_logits = self.out_linear(lstm_output)
        output_softmax = nn.functional.softmax(output_logits,dim=1)
        return output_logits, output_softmax, 1

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
train_helper = Train_Helper()
# Out:
# cuda

# %% [markdown]
# # Learning Stopping Implementation

# %%
# from torchsample.modules import ModuleTrainer
# trainer = ModuleTrainer(model)
# model = ModuleTrainer(Network())
# model.compile(loss='nll_loss', optimizer='adam')
# callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
# model.set_callbacks(callbacks)
# model.fit(x_train, y_train, val_data=(x_test, y_test),num_epoch=200, batch_size=128, verbose=1)
# loss = model.evaluate(x_train, y_train)
# y_pred = model.predict(x_train)

# %% [markdown]
# # TRAINING

# %%
model = SEQUENTIAL_CNN_LSTM(num_emotions=7).to(device)
epochs= 150
batch_size = 32
trained_model, losses, val_losses = train_helper.model_train(model, epochs, batch_size, train_helper.loss_func,  X_train, Y_train, X_val, Y_val, device)
# Out:
# Number of trainable params:  128487
#  Epoch 0: iteration 69/70
# Epoch 0 --> loss:1.5374, acc:39.24%, val_loss:1.4049, val_acc:48.21%
#  Epoch 1: iteration 69/70
# Epoch 1 --> loss:1.0547, acc:61.21%, val_loss:1.5572, val_acc:32.50%
#  Epoch 2: iteration 69/70
# Epoch 2 --> loss:0.8261, acc:71.07%, val_loss:1.2731, val_acc:44.64%
#  Epoch 3: iteration 69/70
# Epoch 3 --> loss:0.6742, acc:76.38%, val_loss:0.8877, val_acc:67.14%
#  Epoch 4: iteration 69/70
# Epoch 4 --> loss:0.5396, acc:80.76%, val_loss:0.8652, val_acc:70.00%
#  Epoch 5: iteration 69/70
# Epoch 5 --> loss:0.4601, acc:84.33%, val_loss:1.3728, val_acc:47.86%
#  Epoch 6: iteration 69/70
# Epoch 6 --> loss:0.3724, acc:87.50%, val_loss:1.1725, val_acc:60.36%
#  Epoch 7: iteration 69/70
# Epoch 7 --> loss:0.3303, acc:88.62%, val_loss:0.8964, val_acc:69.29%
#  Epoch 8: iteration 69/70
# Epoch 8 --> loss:0.2921, acc:90.85%, val_loss:1.2712, val_acc:57.14%
#  Epoch 9: iteration 69/70
# Epoch 9 --> loss:0.2843, acc:91.12%, val_loss:1.0886, val_acc:64.64%
#  Epoch 10: iteration 69/70
# Epoch 10 --> loss:0.2030, acc:93.93%, val_loss:1.9077, val_acc:36.43%
#  Epoch 11: iteration 69/70
# Epoch 11 --> loss:0.1919, acc:93.75%, val_loss:0.8071, val_acc:73.21%
#  Epoch 12: iteration 69/70
# Epoch 12 --> loss:0.1669, acc:95.00%, val_loss:0.6644, val_acc:79.29%
#  Epoch 13: iteration 69/70
# Epoch 13 --> loss:0.1435, acc:95.67%, val_loss:0.6577, val_acc:77.86%
#  Epoch 14: iteration 69/70
# Epoch 14 --> loss:0.1356, acc:96.12%, val_loss:1.2237, val_acc:60.71%
#  Epoch 15: iteration 69/70
# Epoch 15 --> loss:0.1351, acc:95.49%, val_loss:1.4664, val_acc:55.36%
#  Epoch 16: iteration 69/70
# Epoch 16 --> loss:0.1161, acc:96.83%, val_loss:0.9791, val_acc:72.14%
#  Epoch 17: iteration 69/70
# Epoch 17 --> loss:0.1164, acc:96.43%, val_loss:0.6247, val_acc:80.00%
#  Epoch 18: iteration 69/70
# Epoch 18 --> loss:0.0859, acc:97.54%, val_loss:1.2043, val_acc:65.00%
#  Epoch 19: iteration 69/70
# Epoch 19 --> loss:0.1155, acc:96.61%, val_loss:1.0875, val_acc:61.43%
#  Epoch 20: iteration 69/70
# Epoch 20 --> loss:0.0901, acc:97.50%, val_loss:0.9914, val_acc:65.71%
#  Epoch 21: iteration 69/70
# Epoch 21 --> loss:0.0909, acc:96.70%, val_loss:1.0650, val_acc:71.07%
#  Epoch 22: iteration 69/70
# Epoch 22 --> loss:0.0783, acc:97.90%, val_loss:0.5777, val_acc:83.57%
#  Epoch 23: iteration 69/70
# Epoch 23 --> loss:0.0704, acc:97.63%, val_loss:0.9977, val_acc:71.43%
#  Epoch 24: iteration 69/70
# Epoch 24 --> loss:0.1053, acc:96.47%, val_loss:0.6649, val_acc:78.21%
#  Epoch 25: iteration 69/70
# Epoch 25 --> loss:0.0611, acc:98.13%, val_loss:0.8899, val_acc:76.43%
#  Epoch 26: iteration 69/70
# Epoch 26 --> loss:0.0578, acc:98.53%, val_loss:0.9482, val_acc:68.57%
#  Epoch 27: iteration 69/70
# Epoch 27 --> loss:0.0483, acc:98.53%, val_loss:0.9787, val_acc:71.07%
#  Epoch 28: iteration 69/70
# Epoch 28 --> loss:0.0460, acc:98.62%, val_loss:0.9690, val_acc:73.57%
#  Epoch 29: iteration 69/70
# Epoch 29 --> loss:0.0377, acc:99.02%, val_loss:0.8925, val_acc:76.79%
#  Epoch 30: iteration 69/70
# Epoch 30 --> loss:0.0572, acc:98.30%, val_loss:0.4594, val_acc:85.00%
#  Epoch 31: iteration 69/70
# Epoch 31 --> loss:0.0371, acc:99.11%, val_loss:0.6087, val_acc:82.86%
#  Epoch 32: iteration 69/70
# Epoch 32 --> loss:0.0336, acc:98.93%, val_loss:0.9107, val_acc:76.07%
#  Epoch 33: iteration 69/70
# Epoch 33 --> loss:0.0245, acc:99.60%, val_loss:0.8274, val_acc:81.43%
#  Epoch 34: iteration 69/70
# Epoch 34 --> loss:0.0298, acc:99.02%, val_loss:0.8434, val_acc:81.07%
#  Epoch 35: iteration 69/70
# Epoch 35 --> loss:0.0504, acc:98.44%, val_loss:0.6241, val_acc:83.93%
#  Epoch 36: iteration 69/70
# Epoch 36 --> loss:0.0392, acc:98.97%, val_loss:0.6404, val_acc:84.64%
#  Epoch 37: iteration 69/70
# Epoch 37 --> loss:0.0958, acc:96.70%, val_loss:1.3963, val_acc:65.00%
#  Epoch 38: iteration 69/70
# Epoch 38 --> loss:0.0705, acc:97.90%, val_loss:1.3365, val_acc:65.36%
#  Epoch 39: iteration 69/70
# Epoch 39 --> loss:0.0352, acc:98.97%, val_loss:0.8603, val_acc:80.36%
#  Epoch 40: iteration 69/70
# Epoch 40 --> loss:0.0321, acc:99.02%, val_loss:0.9711, val_acc:77.14%
#  Epoch 41: iteration 69/70
# Epoch 41 --> loss:0.0489, acc:98.53%, val_loss:0.7293, val_acc:79.64%
#  Epoch 42: iteration 69/70
# Epoch 42 --> loss:0.0703, acc:97.63%, val_loss:1.2033, val_acc:72.14%
#  Epoch 43: iteration 69/70
# Epoch 43 --> loss:0.0476, acc:98.84%, val_loss:1.3488, val_acc:66.07%
#  Epoch 44: iteration 69/70
# Epoch 44 --> loss:0.0186, acc:99.42%, val_loss:1.0113, val_acc:79.64%
#  Epoch 45: iteration 69/70
# Epoch 45 --> loss:0.0286, acc:99.29%, val_loss:0.9651, val_acc:79.29%
#  Epoch 46: iteration 69/70
# Epoch 46 --> loss:0.0362, acc:98.88%, val_loss:0.7097, val_acc:86.07%
#  Epoch 47: iteration 69/70
# Epoch 47 --> loss:0.0414, acc:98.62%, val_loss:0.9539, val_acc:80.36%
#  Epoch 48: iteration 69/70
# Epoch 48 --> loss:0.0201, acc:99.55%, val_loss:1.0358, val_acc:82.86%
#  Epoch 49: iteration 69/70
# Epoch 49 --> loss:0.0295, acc:99.42%, val_loss:0.6177, val_acc:87.86%
#  Epoch 50: iteration 69/70
# Epoch 50 --> loss:0.0272, acc:99.29%, val_loss:0.9175, val_acc:76.43%
#  Epoch 51: iteration 69/70
# Epoch 51 --> loss:0.0461, acc:98.66%, val_loss:1.3499, val_acc:68.93%
#  Epoch 52: iteration 69/70
# Epoch 52 --> loss:0.0247, acc:99.38%, val_loss:1.4191, val_acc:69.29%
#  Epoch 53: iteration 69/70
# Epoch 53 --> loss:0.0222, acc:99.33%, val_loss:1.0090, val_acc:73.93%
#  Epoch 54: iteration 69/70
# Epoch 54 --> loss:0.0145, acc:99.73%, val_loss:1.0033, val_acc:77.14%
#  Epoch 55: iteration 69/70
# Epoch 55 --> loss:0.0074, acc:99.82%, val_loss:0.8067, val_acc:82.14%
#  Epoch 56: iteration 69/70
# Epoch 56 --> loss:0.0204, acc:99.51%, val_loss:1.5156, val_acc:67.14%
#  Epoch 57: iteration 69/70
# Epoch 57 --> loss:0.0141, acc:99.73%, val_loss:0.7578, val_acc:82.14%
#  Epoch 58: iteration 69/70
# Epoch 58 --> loss:0.0099, acc:99.69%, val_loss:0.6355, val_acc:87.86%
#  Epoch 59: iteration 69/70
# Epoch 59 --> loss:0.0089, acc:99.78%, val_loss:0.7273, val_acc:86.43%
#  Epoch 60: iteration 69/70
# Epoch 60 --> loss:0.0222, acc:99.42%, val_loss:1.2690, val_acc:72.50%
#  Epoch 61: iteration 69/70
# Epoch 61 --> loss:0.0231, acc:99.15%, val_loss:1.1440, val_acc:72.86%
#  Epoch 62: iteration 69/70
# Epoch 62 --> loss:0.0349, acc:98.88%, val_loss:0.6725, val_acc:82.50%
#  Epoch 63: iteration 69/70
# Epoch 63 --> loss:0.0135, acc:99.55%, val_loss:0.2534, val_acc:93.93%
#  Epoch 64: iteration 69/70
# Epoch 64 --> loss:0.0441, acc:98.75%, val_loss:1.3150, val_acc:72.50%
#  Epoch 65: iteration 69/70
# Epoch 65 --> loss:0.0700, acc:97.77%, val_loss:0.9635, val_acc:74.64%
#  Epoch 66: iteration 69/70
# Epoch 66 --> loss:0.0192, acc:99.15%, val_loss:0.6344, val_acc:82.50%
#  Epoch 67: iteration 69/70
# Epoch 67 --> loss:0.0199, acc:99.55%, val_loss:0.4114, val_acc:90.00%
#  Epoch 68: iteration 69/70
# Epoch 68 --> loss:0.0764, acc:97.41%, val_loss:0.7383, val_acc:81.07%
#  Epoch 69: iteration 69/70
# Epoch 69 --> loss:0.0530, acc:98.57%, val_loss:0.6654, val_acc:84.64%
#  Epoch 70: iteration 69/70
# Epoch 70 --> loss:0.0269, acc:99.29%, val_loss:0.4645, val_acc:86.43%
#  Epoch 71: iteration 69/70
# Epoch 71 --> loss:0.0178, acc:99.38%, val_loss:0.5494, val_acc:86.43%
#  Epoch 72: iteration 69/70
# Epoch 72 --> loss:0.0195, acc:99.46%, val_loss:0.8204, val_acc:80.36%
#  Epoch 73: iteration 69/70
# Epoch 73 --> loss:0.0135, acc:99.64%, val_loss:1.1535, val_acc:71.07%
#  Epoch 74: iteration 69/70
# Epoch 74 --> loss:0.0119, acc:99.69%, val_loss:0.9317, val_acc:78.93%
#  Epoch 75: iteration 69/70
# Epoch 75 --> loss:0.0121, acc:99.55%, val_loss:0.7712, val_acc:86.07%
#  Epoch 76: iteration 69/70
# Epoch 76 --> loss:0.0137, acc:99.60%, val_loss:0.8972, val_acc:80.71%
#  Epoch 77: iteration 69/70
# Epoch 77 --> loss:0.0082, acc:99.82%, val_loss:0.5944, val_acc:87.14%
#  Epoch 78: iteration 69/70
# Epoch 78 --> loss:0.0075, acc:99.69%, val_loss:2.1166, val_acc:56.79%
#  Epoch 79: iteration 69/70
# Epoch 79 --> loss:0.0231, acc:99.24%, val_loss:1.0643, val_acc:81.07%
#  Epoch 80: iteration 69/70
# Epoch 80 --> loss:0.0663, acc:98.21%, val_loss:0.8025, val_acc:82.50%
#  Epoch 81: iteration 69/70
# Epoch 81 --> loss:0.0111, acc:99.69%, val_loss:0.6427, val_acc:86.79%
#  Epoch 82: iteration 69/70
# Epoch 82 --> loss:0.0115, acc:99.69%, val_loss:0.7034, val_acc:85.00%
#  Epoch 83: iteration 69/70
# Epoch 83 --> loss:0.0334, acc:99.02%, val_loss:1.1620, val_acc:78.93%
#  Epoch 84: iteration 69/70
# Epoch 84 --> loss:0.0141, acc:99.60%, val_loss:0.7140, val_acc:86.43%
#  Epoch 85: iteration 69/70
# Epoch 85 --> loss:0.0082, acc:99.78%, val_loss:0.9440, val_acc:80.00%
#  Epoch 86: iteration 69/70
# Epoch 86 --> loss:0.0247, acc:98.93%, val_loss:1.1179, val_acc:73.93%
#  Epoch 87: iteration 69/70
# Epoch 87 --> loss:0.0131, acc:99.55%, val_loss:0.5926, val_acc:86.07%
#  Epoch 88: iteration 69/70
# Epoch 88 --> loss:0.0151, acc:99.64%, val_loss:0.8168, val_acc:82.50%
#  Epoch 89: iteration 69/70
# Epoch 89 --> loss:0.0070, acc:99.78%, val_loss:0.6294, val_acc:86.79%
#  Epoch 90: iteration 69/70
# Epoch 90 --> loss:0.0141, acc:99.55%, val_loss:0.6117, val_acc:87.50%
#  Epoch 91: iteration 69/70
# Epoch 91 --> loss:0.0083, acc:99.82%, val_loss:0.9340, val_acc:81.79%
#  Epoch 92: iteration 69/70
# Epoch 92 --> loss:0.0168, acc:99.33%, val_loss:0.4705, val_acc:89.29%
#  Epoch 93: iteration 69/70
# Epoch 93 --> loss:0.0291, acc:99.11%, val_loss:0.4808, val_acc:87.50%
#  Epoch 94: iteration 69/70
# Epoch 94 --> loss:0.0271, acc:99.15%, val_loss:0.6916, val_acc:81.79%
#  Epoch 95: iteration 69/70
# Epoch 95 --> loss:0.0254, acc:99.38%, val_loss:1.6898, val_acc:64.64%
#  Epoch 96: iteration 69/70
# Epoch 96 --> loss:0.0248, acc:99.29%, val_loss:1.4916, val_acc:65.00%
#  Epoch 97: iteration 69/70
# Epoch 97 --> loss:0.0092, acc:99.82%, val_loss:1.1596, val_acc:77.50%
#  Epoch 98: iteration 69/70
# Epoch 98 --> loss:0.0034, acc:100.00%, val_loss:0.8220, val_acc:82.86%
#  Epoch 99: iteration 69/70
# Epoch 99 --> loss:0.0114, acc:99.60%, val_loss:0.9612, val_acc:78.93%
#  Epoch 100: iteration 69/70
# Epoch 100 --> loss:0.0261, acc:99.46%, val_loss:1.0659, val_acc:81.07%
#  Epoch 101: iteration 69/70
# Epoch 101 --> loss:0.0150, acc:99.78%, val_loss:0.8706, val_acc:76.79%
#  Epoch 102: iteration 69/70
# Epoch 102 --> loss:0.0219, acc:99.42%, val_loss:1.7951, val_acc:64.64%
#  Epoch 103: iteration 69/70
# Epoch 103 --> loss:0.0293, acc:99.29%, val_loss:1.3113, val_acc:68.93%
#  Epoch 104: iteration 69/70
# Epoch 104 --> loss:0.0073, acc:99.78%, val_loss:1.3463, val_acc:67.50%
#  Epoch 105: iteration 69/70
# Epoch 105 --> loss:0.0105, acc:99.78%, val_loss:1.0768, val_acc:76.43%
#  Epoch 106: iteration 69/70
# Epoch 106 --> loss:0.0106, acc:99.64%, val_loss:0.6030, val_acc:85.71%
#  Epoch 107: iteration 69/70
# Epoch 107 --> loss:0.0408, acc:98.48%, val_loss:1.8206, val_acc:55.36%
#  Epoch 108: iteration 69/70
# Epoch 108 --> loss:0.0174, acc:99.55%, val_loss:1.1464, val_acc:71.43%
#  Epoch 109: iteration 69/70
# Epoch 109 --> loss:0.0168, acc:99.51%, val_loss:0.9622, val_acc:76.07%
#  Epoch 110: iteration 69/70
# Epoch 110 --> loss:0.0223, acc:99.46%, val_loss:1.0981, val_acc:70.36%
#  Epoch 111: iteration 69/70
# Epoch 111 --> loss:0.0092, acc:99.82%, val_loss:0.8440, val_acc:80.36%
#  Epoch 112: iteration 69/70
# Epoch 112 --> loss:0.0138, acc:99.78%, val_loss:0.7386, val_acc:81.43%
#  Epoch 113: iteration 69/70
# Epoch 113 --> loss:0.0256, acc:99.29%, val_loss:0.9867, val_acc:78.21%
#  Epoch 114: iteration 69/70
# Epoch 114 --> loss:0.0073, acc:99.91%, val_loss:1.3627, val_acc:73.93%
#  Epoch 115: iteration 69/70
# Epoch 115 --> loss:0.0122, acc:99.78%, val_loss:0.8721, val_acc:80.36%
#  Epoch 116: iteration 69/70
# Epoch 116 --> loss:0.0108, acc:99.69%, val_loss:0.9644, val_acc:82.14%
#  Epoch 117: iteration 69/70
# Epoch 117 --> loss:0.0133, acc:99.60%, val_loss:1.7732, val_acc:67.50%
#  Epoch 118: iteration 69/70
# Epoch 118 --> loss:0.0128, acc:99.73%, val_loss:0.4715, val_acc:88.93%
#  Epoch 119: iteration 69/70
# Epoch 119 --> loss:0.0043, acc:99.87%, val_loss:1.1002, val_acc:77.86%
#  Epoch 120: iteration 69/70
# Epoch 120 --> loss:0.0023, acc:99.96%, val_loss:1.2327, val_acc:74.64%
#  Epoch 121: iteration 69/70
# Epoch 121 --> loss:0.0019, acc:100.00%, val_loss:1.1666, val_acc:78.57%
#  Epoch 122: iteration 69/70
# Epoch 122 --> loss:0.0034, acc:99.91%, val_loss:0.5773, val_acc:87.50%
#  Epoch 123: iteration 69/70
# Epoch 123 --> loss:0.0079, acc:99.73%, val_loss:1.2129, val_acc:78.21%
#  Epoch 124: iteration 69/70
# Epoch 124 --> loss:0.0043, acc:99.96%, val_loss:1.5606, val_acc:72.86%
#  Epoch 125: iteration 69/70
# Epoch 125 --> loss:0.0035, acc:99.91%, val_loss:1.5895, val_acc:70.36%
#  Epoch 126: iteration 69/70
# Epoch 126 --> loss:0.0065, acc:99.78%, val_loss:1.8937, val_acc:66.43%
#  Epoch 127: iteration 69/70
# Epoch 127 --> loss:0.0411, acc:99.15%, val_loss:1.5463, val_acc:63.21%
#  Epoch 128: iteration 69/70
# Epoch 128 --> loss:0.0238, acc:99.38%, val_loss:0.6950, val_acc:83.93%
#  Epoch 129: iteration 69/70
# Epoch 129 --> loss:0.0073, acc:99.78%, val_loss:0.7379, val_acc:83.93%
#  Epoch 130: iteration 69/70
# Epoch 130 --> loss:0.0110, acc:99.69%, val_loss:1.1002, val_acc:71.79%
#  Epoch 131: iteration 69/70
# Epoch 131 --> loss:0.0320, acc:98.84%, val_loss:0.6917, val_acc:85.71%
#  Epoch 132: iteration 69/70
# Epoch 132 --> loss:0.0122, acc:99.64%, val_loss:0.7563, val_acc:80.71%
#  Epoch 133: iteration 69/70
# Epoch 133 --> loss:0.0072, acc:99.82%, val_loss:0.4995, val_acc:87.86%
#  Epoch 134: iteration 69/70
# Epoch 134 --> loss:0.0054, acc:99.78%, val_loss:0.3315, val_acc:92.14%
#  Epoch 135: iteration 69/70
# Epoch 135 --> loss:0.0100, acc:99.87%, val_loss:0.1651, val_acc:96.07%
#  Epoch 136: iteration 69/70
# Epoch 136 --> loss:0.0107, acc:99.78%, val_loss:0.1643, val_acc:95.71%
#  Epoch 137: iteration 69/70
# Epoch 137 --> loss:0.0124, acc:99.78%, val_loss:0.6568, val_acc:86.79%
#  Epoch 138: iteration 69/70
# Epoch 138 --> loss:0.0070, acc:99.82%, val_loss:0.4936, val_acc:87.86%
#  Epoch 139: iteration 69/70
# Epoch 139 --> loss:0.0118, acc:99.64%, val_loss:0.9666, val_acc:79.29%
#  Epoch 140: iteration 69/70
# Epoch 140 --> loss:0.0040, acc:99.87%, val_loss:0.8037, val_acc:81.79%
#  Epoch 141: iteration 69/70
# Epoch 141 --> loss:0.0233, acc:99.42%, val_loss:1.1278, val_acc:78.93%
#  Epoch 142: iteration 69/70
# Epoch 142 --> loss:0.0025, acc:99.91%, val_loss:0.9582, val_acc:81.43%
#  Epoch 143: iteration 69/70
# Epoch 143 --> loss:0.0101, acc:99.55%, val_loss:0.7249, val_acc:86.43%
#  Epoch 144: iteration 69/70
# Epoch 144 --> loss:0.0122, acc:99.38%, val_loss:0.5260, val_acc:90.71%
#  Epoch 145: iteration 69/70
# Epoch 145 --> loss:0.0200, acc:99.46%, val_loss:0.3610, val_acc:91.43%
#  Epoch 146: iteration 69/70
# Epoch 146 --> loss:0.0185, acc:99.42%, val_loss:0.7449, val_acc:83.21%
#  Epoch 147: iteration 69/70
# Epoch 147 --> loss:0.0062, acc:99.87%, val_loss:0.3150, val_acc:94.64%
#  Epoch 148: iteration 69/70
# Epoch 148 --> loss:0.0019, acc:100.00%, val_loss:0.4123, val_acc:91.07%
#  Epoch 149: iteration 69/70
# Epoch 149 --> loss:0.0068, acc:99.78%, val_loss:0.4466, val_acc:91.43%

# %% [markdown]
# # Saving the trained model's weights

# %%
saved_trained_weights_file = "sequential_cnn_lstm_150_epochs.pt"

os.makedirs('models', exist_ok=True)
file_path = os.path.join(os.getcwd(),'models')
torch.save(trained_model.state_dict(), os.path.join(file_path, saved_trained_weights_file))
print('Trained Weights saved to'.format(os.path.join(file_path, saved_trained_weights_file)))
# Out:
# Trained Weights saved to

# %% [markdown]
# # Loading model's weights

# %%
loaded_trained_weights_file = "sequential_cnn_lstm_150_epochs.pt"

LOAD_PATH = os.path.join(os.getcwd(),'models')
model = CNN_LSTM(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH, loaded_trained_weights_file)))
print('Weights for Model is loaded from {}'.format(os.path.join(LOAD_PATH, loaded_trained_weights_file)))
# Out:
# Weights for Model is loaded from /home/jovyan/DL Project/models/cnn_lstm_50epochs_batchsize2.pt

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNN_LSTM                                 --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       160
# │    └─BatchNorm2d: 2-2                  32
# │    └─ReLU: 2-3                         --
# │    └─MaxPool2d: 2-4                    --
# │    └─Dropout: 2-5                      --
# │    └─Conv2d: 2-6                       4,640
# │    └─BatchNorm2d: 2-7                  64
# │    └─ReLU: 2-8                         --
# │    └─MaxPool2d: 2-9                    --
# │    └─Dropout: 2-10                     --
# │    └─Conv2d: 2-11                      18,496
# │    └─BatchNorm2d: 2-12                 128
# │    └─ReLU: 2-13                        --
# │    └─MaxPool2d: 2-14                   --
# │    └─Dropout: 2-15                     --
# │    └─Conv2d: 2-16                      36,928
# │    └─BatchNorm2d: 2-17                 (recursive)
# │    └─ReLU: 2-18                        --
# │    └─MaxPool2d: 2-19                   --
# │    └─Dropout: 2-20                     --
# ├─MaxPool2d: 1-2                         --
# ├─LSTM: 1-3                              198,656
# ├─Dropout: 1-4                           --
# ├─Linear: 1-5                            257
# ├─Linear: 1-6                            3,591
# ├─Dropout: 1-7                           --
# ├─Softmax: 1-8                           --
# =================================================================
# Total params: 262,952
# Trainable params: 262,952
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Testing

# %%
validate = train_helper.make_validate_func(model, train_helper.loss_func)
X_test_tensor = torch.tensor(X_test,device="cpu").float()
Y_test_tensor = torch.tensor(Y_test, dtype=torch.long, device="cpu")
testing_loss, testing_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Testing loss is {testing_loss:.3f}')
print(f'Testing accuracy is {testing_acc:.3f}%')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-23a0fd3a4f59> in <module>
#       2 X_test_tensor = torch.tensor(X_test,device="cpu").float()
#       3 Y_test_tensor = torch.tensor(Y_test, dtype=torch.long, device="cpu")
# ----> 4 testing_loss, testing_acc, predictions = validate(X_test_tensor,Y_test_tensor)
#       5 print(f'Testing loss is {testing_loss:.3f}')
#       6 print(f'Testing accuracy is {testing_acc:.3f}%')
#
# ~/DL Project/MelTrainHelper.py in validate(X, Y)
#      32             with torch.no_grad():
#      33                 model.eval()
# ---> 34                 output_logits, output_softmax, attention_weights_norm = model(X)
#      35
#      36                 predictions = torch.argmax(output_softmax,dim=1)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-5-5747b015240d> in forward(self, x)
#      29         self.out_linear = nn.Linear(hidden_size,num_emotions)
#      30     def forward(self,x):
# ---> 31         conv_embedding = self.conv2Dblock(x)
#      32         conv_embedding = torch.flatten(conv_embedding, start_dim=2) # do not flatten batch dimension and time
#      33         #print(conv_embedding.shape)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same

# %%
def infer(model, path, all_mel_specs):
    EMOTIONS= {0:'neutral',1:'happy', 2:'sad', 3:'angry', 4:'fear', 5:'disgust', 6:'ps'}
    n=len(path)
    train_helper = Train_Helper()
    preprocessor = DataPreprocessor()
    validate_top3 = train_helper.make_validate_func_top3(model,train_helper.loss_func)
    if len(path) == 1:
        path = path[0]
        audio, sample_rate = librosa.load(path, duration=3, offset=0.5, sr=48000)
        audio_signal = np.zeros((int(sample_rate*3,)))
        audio_signal[:len(audio)] = audio
        mel_specs = preprocessor.extract_mel_spectogram(audio_signal)
        X_test = mel_specs
        X_test = np.expand_dims(X_test, axis=0)
        X_test = np.concatenate((X_test, all_mel_specs))
        X_test = preprocessor.reshape_scale_data(X_test)
        X_test = X_test[:1]
    else:
        audio_signals = preprocessor.extract_audio_signals(path)
        mel_specs = preprocessor.extract_mel_spectograms(audio_signals)
        mel_specs = np.concatenate((mel_specs, all_mel_specs))
        X_test = preprocessor.reshape_scale_data(mel_specs)
        X_test = X_test[:len(path)]
    Y_test = [1]*n
    X_test_tensor = torch.tensor(X_test,device='cpu').float()
    Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device='cpu')
    test_loss, test_acc, predictions, output_softmax = validate_top3(X_test_tensor,Y_test_tensor)
    
    if len(predictions.tolist()) == 1:
        ground_truth = path.split("_")[-1].split(".")[-2]
        top3_prob, top3 = torch.topk(output_softmax, 3)
        top3 = top3.detach().numpy()
        top3_prob = top3_prob.detach().numpy()
        print("Audio File: ", path)
        print("Predicted Emotions: ",EMOTIONS[top3[0,0]], "\t| Ground Truth: ", ground_truth)
        print("Top 1: ", EMOTIONS[top3[0,0]], "Prob: ", round(top3_prob[0,0]*100, 3),"%", "\t| Top 2: ", EMOTIONS[top3[0,1]], "Prob: ", round(top3_prob[0,1]*100, 3),"%", "\t| Top 3: ", EMOTIONS[top3[0,2]], "Prob: ", round(top3_prob[0,2]*100, 3),"%")
    else:
        print("\n")
        i = 0 
        for pred, file_name in zip(predictions.tolist(), path):
            ground_truth = file_name.split("_")[-1].split(".")[-2]
            
            top3_prob, top3 = torch.topk(output_softmax[i], 3)
            top3 = top3.detach().numpy()
            top3_prob = top3_prob.detach().numpy()
            i += 1
            print("Audio File: ", file_name)
            print("Predicted Emotions: ",EMOTIONS[top3[0]], "\t| Ground Truth: ", ground_truth)
            print("Top 1:", EMOTIONS[top3[0]], "(Prob:", round(top3_prob[0]*100, 2),"%)", "\t| Top 2:", EMOTIONS[top3[1]], "(Prob:", round(top3_prob[1]*100, 2),"%)", "\t| Top 3:", EMOTIONS[top3[2]], "(Prob:", round(top3_prob[2]*100, 2),"%)\n")
    return

# %% [markdown]
# # Confusion Matrix

# %%
predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
print(EMOTIONS)
EMOTIONS= {0:'neutral',1:'happy', 2:'sad', 3:'angry', 4:'fear', 5:'disgust', 6:'ps'}
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])

# %% [markdown]
# # Visualizing mel spectrograms

# %%
audio = preprocessor.extract_audio_signals(["./TESS/YAF_happy/YAF_wife_happy.wav"])

Audio(Y,rate=48000)

# %%
librosa.display.specshow(mel_spectograms[2].squeeze(), y_axis='mel', x_axis='time',cmap='magma')
Audio(audio,rate=48000)

# %% [markdown]
# # Inferring Single or Multiple Samples

# %%
#Inferring Single Sample
#single_test = "./TESS/YAF_sad/YAF_wife_sad.wav"
single_test = "./CREMA_D/happy/1004_IEO_HAP_LO.wav"
infer(model,[single_test],mel_spectograms)
audio = preprocessor.extract_audio_signals([single_test])
Audio(audio,rate=48000)
# Out:
# Audio File:  ./CREMA_D/happy/1004_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1:  disgust Prob:  54.003 % 	| Top 2:  ps Prob:  41.182 % 	| Top 3:  neutral Prob:  2.27 %
#  extract_audio_signals: Processed 0/1 files
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Inferring a list of Samples
file_ls = ["./TESS/YAF_sad/YAF_wife_sad.wav","./TESS/YAF_fear/YAF_wife_fear.wav","./TESS/YAF_happy/YAF_wife_happy.wav","./TESS/YAF_neutral/YAF_wife_neutral.wav"]
infer(model, file_ls ,mel_spectograms)
# Out:
#  extract_mel_spectograms: Processed 3/4 files
#
# Audio File:  ./TESS/YAF_sad/YAF_wife_sad.wav
# Predicted Emotions:  sad 	| Ground Truth:  sad
# Top 1: sad (Prob: 99.77 %) 	| Top 2: angry (Prob: 0.06 %) 	| Top 3: fear (Prob: 0.06 %)
#
# Audio File:  ./TESS/YAF_fear/YAF_wife_fear.wav
# Predicted Emotions:  fear 	| Ground Truth:  fear
# Top 1: fear (Prob: 99.92 %) 	| Top 2: angry (Prob: 0.04 %) 	| Top 3: ps (Prob: 0.02 %)
#
# Audio File:  ./TESS/YAF_happy/YAF_wife_happy.wav
# Predicted Emotions:  happy 	| Ground Truth:  happy
# Top 1: happy (Prob: 100.0 %) 	| Top 2: angry (Prob: 0.0 %) 	| Top 3: fear (Prob: 0.0 %)
#
# Audio File:  ./TESS/YAF_neutral/YAF_wife_neutral.wav
# Predicted Emotions:  neutral 	| Ground Truth:  neutral
# Top 1: neutral (Prob: 98.16 %) 	| Top 2: angry (Prob: 0.85 %) 	| Top 3: ps (Prob: 0.69 %)

# %%
#Inferring a folder of Samples
folder_name = "./TESS/YAF_happy/"
#folder_name = "./CREMA_D/happy/"
folder = os.listdir(folder_name)
folder = [folder_name+file for file in folder]
infer(model, folder, mel_spectograms)
# Out:
#  extract_mel_spectograms: Processed 499/500 files
#
# Audio File:  ./CREMA_D/happy/1015_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 85.94 %) 	| Top 2: fear (Prob: 5.46 %) 	| Top 3: angry (Prob: 5.38 %)
#
# Audio File:  ./CREMA_D/happy/1025_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 59.73 %) 	| Top 2: disgust (Prob: 24.68 %) 	| Top 3: angry (Prob: 7.03 %)
#
# Audio File:  ./CREMA_D/happy/1046_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 50.21 %) 	| Top 2: fear (Prob: 33.33 %) 	| Top 3: neutral (Prob: 11.04 %)
#
# Audio File:  ./CREMA_D/happy/1018_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 39.08 %) 	| Top 2: fear (Prob: 32.28 %) 	| Top 3: ps (Prob: 26.33 %)
#
# Audio File:  ./CREMA_D/happy/1074_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 96.8 %) 	| Top 2: fear (Prob: 1.32 %) 	| Top 3: angry (Prob: 1.06 %)
#
# Audio File:  ./CREMA_D/happy/1026_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.09 %) 	| Top 2: neutral (Prob: 17.7 %) 	| Top 3: ps (Prob: 16.85 %)
#
# Audio File:  ./CREMA_D/happy/1069_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 56.03 %) 	| Top 2: ps (Prob: 30.59 %) 	| Top 3: angry (Prob: 9.51 %)
#
# Audio File:  ./CREMA_D/happy/1033_IEO_HAP_LO.wav
# Predicted Emotions:  ps 	| Ground Truth:  LO
# Top 1: ps (Prob: 48.91 %) 	| Top 2: angry (Prob: 12.5 %) 	| Top 3: sad (Prob: 12.45 %)
#
# Audio File:  ./CREMA_D/happy/1044_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 86.14 %) 	| Top 2: ps (Prob: 10.83 %) 	| Top 3: sad (Prob: 2.58 %)
#
# Audio File:  ./CREMA_D/happy/1065_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 58.05 %) 	| Top 2: ps (Prob: 36.71 %) 	| Top 3: fear (Prob: 2.29 %)
#
# Audio File:  ./CREMA_D/happy/1018_IEO_HAP_MD.wav
# Predicted Emotions:  angry 	| Ground Truth:  MD
# Top 1: angry (Prob: 37.25 %) 	| Top 2: disgust (Prob: 26.72 %) 	| Top 3: neutral (Prob: 20.19 %)
#
# Audio File:  ./CREMA_D/happy/1001_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 66.23 %) 	| Top 2: angry (Prob: 20.96 %) 	| Top 3: disgust (Prob: 9.07 %)
#
# Audio File:  ./CREMA_D/happy/1026_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 64.29 %) 	| Top 2: angry (Prob: 13.07 %) 	| Top 3: fear (Prob: 7.96 %)
#
# Audio File:  ./CREMA_D/happy/1055_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.4 %) 	| Top 2: ps (Prob: 41.69 %) 	| Top 3: sad (Prob: 4.02 %)
#
# Audio File:  ./CREMA_D/happy/1072_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 79.29 %) 	| Top 2: disgust (Prob: 17.55 %) 	| Top 3: fear (Prob: 2.92 %)
#
# Audio File:  ./CREMA_D/happy/1068_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 60.07 %) 	| Top 2: ps (Prob: 27.43 %) 	| Top 3: angry (Prob: 7.06 %)
#
# Audio File:  ./CREMA_D/happy/1041_ITS_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 33.57 %) 	| Top 2: sad (Prob: 25.2 %) 	| Top 3: disgust (Prob: 20.44 %)
#
# Audio File:  ./CREMA_D/happy/1031_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 76.63 %) 	| Top 2: ps (Prob: 13.7 %) 	| Top 3: sad (Prob: 9.55 %)
#
# Audio File:  ./CREMA_D/happy/1053_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 54.34 %) 	| Top 2: disgust (Prob: 26.81 %) 	| Top 3: fear (Prob: 6.08 %)
#
# Audio File:  ./CREMA_D/happy/1004_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 64.33 %) 	| Top 2: ps (Prob: 31.25 %) 	| Top 3: neutral (Prob: 2.58 %)
#
# Audio File:  ./CREMA_D/happy/1012_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 88.26 %) 	| Top 2: ps (Prob: 10.76 %) 	| Top 3: sad (Prob: 0.88 %)
#
# Audio File:  ./CREMA_D/happy/1009_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 45.12 %) 	| Top 2: disgust (Prob: 44.04 %) 	| Top 3: fear (Prob: 10.55 %)
#
# Audio File:  ./CREMA_D/happy/1068_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 63.74 %) 	| Top 2: disgust (Prob: 34.44 %) 	| Top 3: sad (Prob: 1.06 %)
#
# Audio File:  ./CREMA_D/happy/1063_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 37.04 %) 	| Top 2: angry (Prob: 23.68 %) 	| Top 3: disgust (Prob: 21.37 %)
#
# Audio File:  ./CREMA_D/happy/1074_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 54.56 %) 	| Top 2: ps (Prob: 39.0 %) 	| Top 3: fear (Prob: 5.98 %)
#
# Audio File:  ./CREMA_D/happy/1008_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 74.44 %) 	| Top 2: ps (Prob: 23.26 %) 	| Top 3: fear (Prob: 1.93 %)
#
# Audio File:  ./CREMA_D/happy/1023_WSI_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 51.09 %) 	| Top 2: ps (Prob: 23.74 %) 	| Top 3: fear (Prob: 17.17 %)
#
# Audio File:  ./CREMA_D/happy/1058_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 87.37 %) 	| Top 2: disgust (Prob: 12.47 %) 	| Top 3: fear (Prob: 0.11 %)
#
# Audio File:  ./CREMA_D/happy/1023_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 74.78 %) 	| Top 2: angry (Prob: 17.32 %) 	| Top 3: ps (Prob: 2.9 %)
#
# Audio File:  ./CREMA_D/happy/1024_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 84.69 %) 	| Top 2: ps (Prob: 9.03 %) 	| Top 3: neutral (Prob: 4.84 %)
#
# Audio File:  ./CREMA_D/happy/1004_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 71.59 %) 	| Top 2: ps (Prob: 24.17 %) 	| Top 3: sad (Prob: 3.76 %)
#
# Audio File:  ./CREMA_D/happy/1024_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 75.47 %) 	| Top 2: ps (Prob: 21.7 %) 	| Top 3: fear (Prob: 1.69 %)
#
# Audio File:  ./CREMA_D/happy/1074_IEO_HAP_LO.wav
# Predicted Emotions:  angry 	| Ground Truth:  LO
# Top 1: angry (Prob: 67.26 %) 	| Top 2: disgust (Prob: 16.32 %) 	| Top 3: ps (Prob: 11.01 %)
#
# Audio File:  ./CREMA_D/happy/1067_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 40.24 %) 	| Top 2: sad (Prob: 32.47 %) 	| Top 3: disgust (Prob: 16.45 %)
#
# Audio File:  ./CREMA_D/happy/1043_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 59.16 %) 	| Top 2: ps (Prob: 27.75 %) 	| Top 3: fear (Prob: 12.48 %)
#
# Audio File:  ./CREMA_D/happy/1030_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 86.2 %) 	| Top 2: disgust (Prob: 11.49 %) 	| Top 3: sad (Prob: 1.71 %)
#
# Audio File:  ./CREMA_D/happy/1012_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 66.11 %) 	| Top 2: ps (Prob: 32.26 %) 	| Top 3: sad (Prob: 1.15 %)
#
# Audio File:  ./CREMA_D/happy/1032_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 82.58 %) 	| Top 2: sad (Prob: 9.35 %) 	| Top 3: ps (Prob: 5.69 %)
#
# Audio File:  ./CREMA_D/happy/1025_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 42.2 %) 	| Top 2: angry (Prob: 38.73 %) 	| Top 3: fear (Prob: 9.92 %)
#
# Audio File:  ./CREMA_D/happy/1007_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 88.19 %) 	| Top 2: sad (Prob: 9.29 %) 	| Top 3: ps (Prob: 2.47 %)
#
# Audio File:  ./CREMA_D/happy/1041_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 34.25 %) 	| Top 2: neutral (Prob: 33.12 %) 	| Top 3: disgust (Prob: 24.01 %)
#
# Audio File:  ./CREMA_D/happy/1056_IEO_HAP_LO.wav
# Predicted Emotions:  angry 	| Ground Truth:  LO
# Top 1: angry (Prob: 31.08 %) 	| Top 2: disgust (Prob: 30.58 %) 	| Top 3: ps (Prob: 12.44 %)
#
# Audio File:  ./CREMA_D/happy/1034_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 69.74 %) 	| Top 2: disgust (Prob: 20.74 %) 	| Top 3: sad (Prob: 2.76 %)
#
# Audio File:  ./CREMA_D/happy/1009_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 57.63 %) 	| Top 2: ps (Prob: 40.37 %) 	| Top 3: fear (Prob: 1.38 %)
#
# Audio File:  ./CREMA_D/happy/1058_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 79.93 %) 	| Top 2: disgust (Prob: 18.47 %) 	| Top 3: angry (Prob: 0.92 %)
#
# Audio File:  ./CREMA_D/happy/1070_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 53.88 %) 	| Top 2: disgust (Prob: 28.87 %) 	| Top 3: angry (Prob: 6.21 %)
#
# Audio File:  ./CREMA_D/happy/1042_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 37.63 %) 	| Top 2: disgust (Prob: 27.56 %) 	| Top 3: fear (Prob: 26.99 %)
#
# Audio File:  ./CREMA_D/happy/1077_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 76.6 %) 	| Top 2: disgust (Prob: 16.27 %) 	| Top 3: sad (Prob: 3.78 %)
#
# Audio File:  ./CREMA_D/happy/1076_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 60.66 %) 	| Top 2: ps (Prob: 37.33 %) 	| Top 3: fear (Prob: 0.86 %)
#
# Audio File:  ./CREMA_D/happy/1006_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 70.11 %) 	| Top 2: ps (Prob: 25.02 %) 	| Top 3: sad (Prob: 4.29 %)
#
# Audio File:  ./CREMA_D/happy/1070_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 88.54 %) 	| Top 2: disgust (Prob: 10.7 %) 	| Top 3: fear (Prob: 0.41 %)
#
# Audio File:  ./CREMA_D/happy/1023_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 91.25 %) 	| Top 2: disgust (Prob: 2.77 %) 	| Top 3: fear (Prob: 2.16 %)
#
# Audio File:  ./CREMA_D/happy/1048_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 69.91 %) 	| Top 2: disgust (Prob: 20.87 %) 	| Top 3: fear (Prob: 3.08 %)
#
# Audio File:  ./CREMA_D/happy/1023_ITS_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 43.04 %) 	| Top 2: ps (Prob: 31.62 %) 	| Top 3: disgust (Prob: 11.94 %)
#
# Audio File:  ./CREMA_D/happy/1037_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 61.29 %) 	| Top 2: ps (Prob: 38.56 %) 	| Top 3: fear (Prob: 0.07 %)
#
# Audio File:  ./CREMA_D/happy/1053_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 27.79 %) 	| Top 2: angry (Prob: 26.62 %) 	| Top 3: ps (Prob: 14.14 %)
#
# Audio File:  ./CREMA_D/happy/1063_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 76.1 %) 	| Top 2: ps (Prob: 22.82 %) 	| Top 3: fear (Prob: 0.41 %)
#
# Audio File:  ./CREMA_D/happy/1002_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 61.91 %) 	| Top 2: disgust (Prob: 35.05 %) 	| Top 3: fear (Prob: 2.16 %)
#
# Audio File:  ./CREMA_D/happy/1050_TIE_HAP_XX.wav
# Predicted Emotions:  sad 	| Ground Truth:  XX
# Top 1: sad (Prob: 41.3 %) 	| Top 2: disgust (Prob: 36.94 %) 	| Top 3: ps (Prob: 20.78 %)
#
# Audio File:  ./CREMA_D/happy/1064_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 96.83 %) 	| Top 2: sad (Prob: 3.02 %) 	| Top 3: ps (Prob: 0.14 %)
#
# Audio File:  ./CREMA_D/happy/1029_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 34.65 %) 	| Top 2: ps (Prob: 31.97 %) 	| Top 3: sad (Prob: 11.07 %)
#
# Audio File:  ./CREMA_D/happy/1053_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 60.83 %) 	| Top 2: ps (Prob: 22.01 %) 	| Top 3: happy (Prob: 8.58 %)
#
# Audio File:  ./CREMA_D/happy/1007_TSI_HAP_XX.wav
# Predicted Emotions:  sad 	| Ground Truth:  XX
# Top 1: sad (Prob: 47.77 %) 	| Top 2: ps (Prob: 18.6 %) 	| Top 3: disgust (Prob: 12.34 %)
#
# Audio File:  ./CREMA_D/happy/1066_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 64.46 %) 	| Top 2: ps (Prob: 25.33 %) 	| Top 3: angry (Prob: 5.78 %)
#
# Audio File:  ./CREMA_D/happy/1078_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.57 %) 	| Top 2: fear (Prob: 12.24 %) 	| Top 3: angry (Prob: 10.84 %)
#
# Audio File:  ./CREMA_D/happy/1046_TAI_HAP_XX.wav
# Predicted Emotions:  fear 	| Ground Truth:  XX
# Top 1: fear (Prob: 51.95 %) 	| Top 2: disgust (Prob: 25.79 %) 	| Top 3: ps (Prob: 13.01 %)
#
# Audio File:  ./CREMA_D/happy/1016_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 33.5 %) 	| Top 2: sad (Prob: 17.46 %) 	| Top 3: disgust (Prob: 17.36 %)
#
# Audio File:  ./CREMA_D/happy/1037_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 88.06 %) 	| Top 2: ps (Prob: 10.62 %) 	| Top 3: sad (Prob: 0.69 %)
#
# Audio File:  ./CREMA_D/happy/1014_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 97.46 %) 	| Top 2: disgust (Prob: 2.39 %) 	| Top 3: fear (Prob: 0.08 %)
#
# Audio File:  ./CREMA_D/happy/1062_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 46.95 %) 	| Top 2: disgust (Prob: 37.12 %) 	| Top 3: sad (Prob: 13.32 %)
#
# Audio File:  ./CREMA_D/happy/1048_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 86.96 %) 	| Top 2: angry (Prob: 4.09 %) 	| Top 3: disgust (Prob: 3.21 %)
#
# Audio File:  ./CREMA_D/happy/1061_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 48.62 %) 	| Top 2: disgust (Prob: 44.38 %) 	| Top 3: neutral (Prob: 1.89 %)
#
# Audio File:  ./CREMA_D/happy/1005_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 53.14 %) 	| Top 2: disgust (Prob: 42.09 %) 	| Top 3: neutral (Prob: 2.97 %)
#
# Audio File:  ./CREMA_D/happy/1063_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 52.64 %) 	| Top 2: disgust (Prob: 25.33 %) 	| Top 3: fear (Prob: 14.17 %)
#
# Audio File:  ./CREMA_D/happy/1019_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 50.62 %) 	| Top 2: disgust (Prob: 45.0 %) 	| Top 3: sad (Prob: 2.69 %)
#
# Audio File:  ./CREMA_D/happy/1020_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 84.48 %) 	| Top 2: ps (Prob: 12.65 %) 	| Top 3: fear (Prob: 0.87 %)
#
# Audio File:  ./CREMA_D/happy/1007_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 97.17 %) 	| Top 2: sad (Prob: 1.89 %) 	| Top 3: ps (Prob: 0.76 %)
#
# Audio File:  ./CREMA_D/happy/1006_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 56.89 %) 	| Top 2: ps (Prob: 42.64 %) 	| Top 3: sad (Prob: 0.26 %)
#
# Audio File:  ./CREMA_D/happy/1074_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 81.46 %) 	| Top 2: ps (Prob: 7.42 %) 	| Top 3: angry (Prob: 6.63 %)
#
# Audio File:  ./CREMA_D/happy/1038_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 66.84 %) 	| Top 2: ps (Prob: 30.34 %) 	| Top 3: fear (Prob: 2.3 %)
#
# Audio File:  ./CREMA_D/happy/1018_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 48.41 %) 	| Top 2: fear (Prob: 38.49 %) 	| Top 3: ps (Prob: 10.42 %)
#
# Audio File:  ./CREMA_D/happy/1062_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 33.93 %) 	| Top 2: disgust (Prob: 25.11 %) 	| Top 3: sad (Prob: 17.34 %)
#
# Audio File:  ./CREMA_D/happy/1060_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 61.98 %) 	| Top 2: ps (Prob: 16.72 %) 	| Top 3: neutral (Prob: 10.68 %)
#
# Audio File:  ./CREMA_D/happy/1004_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.39 %) 	| Top 2: ps (Prob: 46.27 %) 	| Top 3: sad (Prob: 0.18 %)
#
# Audio File:  ./CREMA_D/happy/1005_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 99.01 %) 	| Top 2: disgust (Prob: 0.76 %) 	| Top 3: fear (Prob: 0.09 %)
#
# Audio File:  ./CREMA_D/happy/1054_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 71.75 %) 	| Top 2: ps (Prob: 25.26 %) 	| Top 3: sad (Prob: 1.5 %)
#
# Audio File:  ./CREMA_D/happy/1001_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 52.83 %) 	| Top 2: ps (Prob: 27.41 %) 	| Top 3: angry (Prob: 8.03 %)
#
# Audio File:  ./CREMA_D/happy/1040_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 75.19 %) 	| Top 2: ps (Prob: 21.19 %) 	| Top 3: sad (Prob: 1.6 %)
#
# Audio File:  ./CREMA_D/happy/1043_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 68.66 %) 	| Top 2: ps (Prob: 18.63 %) 	| Top 3: fear (Prob: 12.14 %)
#
# Audio File:  ./CREMA_D/happy/1004_TSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.78 %) 	| Top 2: ps (Prob: 6.3 %) 	| Top 3: neutral (Prob: 0.31 %)
#
# Audio File:  ./CREMA_D/happy/1028_IEO_HAP_HI.wav
# Predicted Emotions:  neutral 	| Ground Truth:  HI
# Top 1: neutral (Prob: 35.55 %) 	| Top 2: ps (Prob: 28.48 %) 	| Top 3: disgust (Prob: 22.4 %)
#
# Audio File:  ./CREMA_D/happy/1005_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 97.69 %) 	| Top 2: ps (Prob: 1.5 %) 	| Top 3: sad (Prob: 0.35 %)
#
# Audio File:  ./CREMA_D/happy/1012_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 82.79 %) 	| Top 2: happy (Prob: 5.73 %) 	| Top 3: fear (Prob: 4.86 %)
#
# Audio File:  ./CREMA_D/happy/1009_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 64.38 %) 	| Top 2: angry (Prob: 21.19 %) 	| Top 3: fear (Prob: 4.5 %)
#
# Audio File:  ./CREMA_D/happy/1059_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 35.56 %) 	| Top 2: fear (Prob: 31.88 %) 	| Top 3: ps (Prob: 20.3 %)
#
# Audio File:  ./CREMA_D/happy/1059_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 90.45 %) 	| Top 2: disgust (Prob: 6.98 %) 	| Top 3: fear (Prob: 1.28 %)
#
# Audio File:  ./CREMA_D/happy/1016_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 73.06 %) 	| Top 2: ps (Prob: 26.65 %) 	| Top 3: sad (Prob: 0.16 %)
#
# Audio File:  ./CREMA_D/happy/1005_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 99.59 %) 	| Top 2: sad (Prob: 0.29 %) 	| Top 3: ps (Prob: 0.08 %)
#
# Audio File:  ./CREMA_D/happy/1015_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 38.14 %) 	| Top 2: ps (Prob: 25.23 %) 	| Top 3: angry (Prob: 18.08 %)
#
# Audio File:  ./CREMA_D/happy/1002_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 57.17 %) 	| Top 2: disgust (Prob: 35.51 %) 	| Top 3: sad (Prob: 6.3 %)
#
# Audio File:  ./CREMA_D/happy/1055_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 95.67 %) 	| Top 2: ps (Prob: 3.77 %) 	| Top 3: sad (Prob: 0.53 %)
#
# Audio File:  ./CREMA_D/happy/1039_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 87.91 %) 	| Top 2: disgust (Prob: 11.75 %) 	| Top 3: fear (Prob: 0.18 %)
#
# Audio File:  ./CREMA_D/happy/1021_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 80.54 %) 	| Top 2: ps (Prob: 18.44 %) 	| Top 3: sad (Prob: 0.41 %)
#
# Audio File:  ./CREMA_D/happy/1043_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 60.6 %) 	| Top 2: sad (Prob: 16.57 %) 	| Top 3: angry (Prob: 6.48 %)
#
# Audio File:  ./CREMA_D/happy/1028_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 62.36 %) 	| Top 2: ps (Prob: 25.17 %) 	| Top 3: fear (Prob: 11.17 %)
#
# Audio File:  ./CREMA_D/happy/1012_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 70.08 %) 	| Top 2: ps (Prob: 27.13 %) 	| Top 3: sad (Prob: 2.49 %)
#
# Audio File:  ./CREMA_D/happy/1009_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 85.72 %) 	| Top 2: fear (Prob: 5.99 %) 	| Top 3: angry (Prob: 4.36 %)
#
# Audio File:  ./CREMA_D/happy/1075_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 97.5 %) 	| Top 2: ps (Prob: 1.48 %) 	| Top 3: neutral (Prob: 0.37 %)
#
# Audio File:  ./CREMA_D/happy/1036_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 67.48 %) 	| Top 2: disgust (Prob: 26.83 %) 	| Top 3: sad (Prob: 4.26 %)
#
# Audio File:  ./CREMA_D/happy/1055_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 51.69 %) 	| Top 2: angry (Prob: 34.63 %) 	| Top 3: ps (Prob: 5.63 %)
#
# Audio File:  ./CREMA_D/happy/1076_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 63.21 %) 	| Top 2: ps (Prob: 35.07 %) 	| Top 3: sad (Prob: 0.67 %)
#
# Audio File:  ./CREMA_D/happy/1064_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.86 %) 	| Top 2: sad (Prob: 27.11 %) 	| Top 3: ps (Prob: 0.04 %)
#
# Audio File:  ./CREMA_D/happy/1044_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 74.24 %) 	| Top 2: disgust (Prob: 16.42 %) 	| Top 3: fear (Prob: 6.46 %)
#
# Audio File:  ./CREMA_D/happy/1013_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 52.46 %) 	| Top 2: fear (Prob: 41.73 %) 	| Top 3: angry (Prob: 3.19 %)
#
# Audio File:  ./CREMA_D/happy/1014_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 94.13 %) 	| Top 2: disgust (Prob: 4.07 %) 	| Top 3: fear (Prob: 0.8 %)
#
# Audio File:  ./CREMA_D/happy/1020_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 38.36 %) 	| Top 2: disgust (Prob: 36.11 %) 	| Top 3: happy (Prob: 10.46 %)
#
# Audio File:  ./CREMA_D/happy/1034_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 93.04 %) 	| Top 2: fear (Prob: 2.08 %) 	| Top 3: angry (Prob: 2.07 %)
#
# Audio File:  ./CREMA_D/happy/1008_TSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 99.3 %) 	| Top 2: ps (Prob: 0.49 %) 	| Top 3: sad (Prob: 0.21 %)
#
# Audio File:  ./CREMA_D/happy/1073_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 55.92 %) 	| Top 2: ps (Prob: 33.12 %) 	| Top 3: sad (Prob: 10.46 %)
#
# Audio File:  ./CREMA_D/happy/1030_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 88.58 %) 	| Top 2: ps (Prob: 10.04 %) 	| Top 3: sad (Prob: 1.15 %)
#
# Audio File:  ./CREMA_D/happy/1021_IEO_HAP_LO.wav
# Predicted Emotions:  neutral 	| Ground Truth:  LO
# Top 1: neutral (Prob: 40.45 %) 	| Top 2: ps (Prob: 35.32 %) 	| Top 3: disgust (Prob: 13.5 %)
#
# Audio File:  ./CREMA_D/happy/1070_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 92.74 %) 	| Top 2: disgust (Prob: 2.62 %) 	| Top 3: happy (Prob: 1.87 %)
#
# Audio File:  ./CREMA_D/happy/1074_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 84.26 %) 	| Top 2: ps (Prob: 13.47 %) 	| Top 3: fear (Prob: 2.1 %)
#
# Audio File:  ./CREMA_D/happy/1068_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 99.73 %) 	| Top 2: ps (Prob: 0.26 %) 	| Top 3: sad (Prob: 0.01 %)
#
# Audio File:  ./CREMA_D/happy/1018_IEO_HAP_LO.wav
# Predicted Emotions:  neutral 	| Ground Truth:  LO
# Top 1: neutral (Prob: 72.3 %) 	| Top 2: disgust (Prob: 12.93 %) 	| Top 3: ps (Prob: 6.64 %)
#
# Audio File:  ./CREMA_D/happy/1068_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 91.49 %) 	| Top 2: ps (Prob: 6.23 %) 	| Top 3: sad (Prob: 1.24 %)
#
# Audio File:  ./CREMA_D/happy/1062_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 22.71 %) 	| Top 2: neutral (Prob: 20.97 %) 	| Top 3: sad (Prob: 17.49 %)
#
# Audio File:  ./CREMA_D/happy/1003_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 95.98 %) 	| Top 2: ps (Prob: 3.71 %) 	| Top 3: sad (Prob: 0.17 %)
#
# Audio File:  ./CREMA_D/happy/1045_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 41.97 %) 	| Top 2: disgust (Prob: 34.91 %) 	| Top 3: angry (Prob: 10.54 %)
#
# Audio File:  ./CREMA_D/happy/1002_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 83.54 %) 	| Top 2: ps (Prob: 14.11 %) 	| Top 3: fear (Prob: 1.06 %)
#
# Audio File:  ./CREMA_D/happy/1077_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 88.39 %) 	| Top 2: disgust (Prob: 11.16 %) 	| Top 3: angry (Prob: 0.27 %)
#
# Audio File:  ./CREMA_D/happy/1048_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 88.21 %) 	| Top 2: ps (Prob: 8.62 %) 	| Top 3: sad (Prob: 3.14 %)
#
# Audio File:  ./CREMA_D/happy/1029_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 79.27 %) 	| Top 2: angry (Prob: 8.5 %) 	| Top 3: fear (Prob: 4.76 %)
#
# Audio File:  ./CREMA_D/happy/1017_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 34.44 %) 	| Top 2: disgust (Prob: 25.42 %) 	| Top 3: sad (Prob: 14.68 %)
#
# Audio File:  ./CREMA_D/happy/1045_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 35.32 %) 	| Top 2: disgust (Prob: 31.9 %) 	| Top 3: neutral (Prob: 30.71 %)
#
# Audio File:  ./CREMA_D/happy/1010_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 84.43 %) 	| Top 2: fear (Prob: 10.31 %) 	| Top 3: disgust (Prob: 2.59 %)
#
# Audio File:  ./CREMA_D/happy/1040_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.54 %) 	| Top 2: ps (Prob: 13.6 %) 	| Top 3: neutral (Prob: 5.9 %)
#
# Audio File:  ./CREMA_D/happy/1006_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 78.71 %) 	| Top 2: ps (Prob: 15.56 %) 	| Top 3: sad (Prob: 2.79 %)
#
# Audio File:  ./CREMA_D/happy/1038_IEO_HAP_LO.wav
# Predicted Emotions:  ps 	| Ground Truth:  LO
# Top 1: ps (Prob: 75.38 %) 	| Top 2: disgust (Prob: 17.33 %) 	| Top 3: neutral (Prob: 3.7 %)
#
# Audio File:  ./CREMA_D/happy/1004_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 50.28 %) 	| Top 2: ps (Prob: 48.12 %) 	| Top 3: fear (Prob: 1.23 %)
#
# Audio File:  ./CREMA_D/happy/1067_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 36.46 %) 	| Top 2: ps (Prob: 31.37 %) 	| Top 3: sad (Prob: 21.45 %)
#
# Audio File:  ./CREMA_D/happy/1043_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 64.03 %) 	| Top 2: ps (Prob: 33.65 %) 	| Top 3: sad (Prob: 1.0 %)
#
# Audio File:  ./CREMA_D/happy/1039_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 68.32 %) 	| Top 2: disgust (Prob: 18.97 %) 	| Top 3: fear (Prob: 5.39 %)
#
# Audio File:  ./CREMA_D/happy/1069_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 41.13 %) 	| Top 2: disgust (Prob: 35.92 %) 	| Top 3: fear (Prob: 12.44 %)
#
# Audio File:  ./CREMA_D/happy/1052_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 64.15 %) 	| Top 2: fear (Prob: 16.54 %) 	| Top 3: disgust (Prob: 16.47 %)
#
# Audio File:  ./CREMA_D/happy/1033_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 68.0 %) 	| Top 2: neutral (Prob: 13.78 %) 	| Top 3: fear (Prob: 10.12 %)
#
# Audio File:  ./CREMA_D/happy/1059_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 83.51 %) 	| Top 2: fear (Prob: 13.98 %) 	| Top 3: disgust (Prob: 1.96 %)
#
# Audio File:  ./CREMA_D/happy/1005_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 65.46 %) 	| Top 2: ps (Prob: 11.8 %) 	| Top 3: sad (Prob: 10.25 %)
#
# Audio File:  ./CREMA_D/happy/1001_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 78.9 %) 	| Top 2: disgust (Prob: 11.44 %) 	| Top 3: sad (Prob: 3.01 %)
#
# Audio File:  ./CREMA_D/happy/1007_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 74.81 %) 	| Top 2: sad (Prob: 24.58 %) 	| Top 3: ps (Prob: 0.49 %)
#
# Audio File:  ./CREMA_D/happy/1041_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 81.27 %) 	| Top 2: disgust (Prob: 10.78 %) 	| Top 3: sad (Prob: 4.84 %)
#
# Audio File:  ./CREMA_D/happy/1025_TSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.84 %) 	| Top 2: ps (Prob: 3.91 %) 	| Top 3: sad (Prob: 1.64 %)
#
# Audio File:  ./CREMA_D/happy/1069_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 53.3 %) 	| Top 2: disgust (Prob: 29.11 %) 	| Top 3: neutral (Prob: 8.8 %)
#
# Audio File:  ./CREMA_D/happy/1076_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 74.6 %) 	| Top 2: disgust (Prob: 18.62 %) 	| Top 3: neutral (Prob: 5.38 %)
#
# Audio File:  ./CREMA_D/happy/1013_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 87.69 %) 	| Top 2: fear (Prob: 5.82 %) 	| Top 3: disgust (Prob: 4.12 %)
#
# Audio File:  ./CREMA_D/happy/1022_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 57.74 %) 	| Top 2: disgust (Prob: 18.77 %) 	| Top 3: sad (Prob: 13.64 %)
#
# Audio File:  ./CREMA_D/happy/1048_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 94.55 %) 	| Top 2: ps (Prob: 3.61 %) 	| Top 3: sad (Prob: 1.8 %)
#
# Audio File:  ./CREMA_D/happy/1014_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 65.31 %) 	| Top 2: ps (Prob: 32.28 %) 	| Top 3: neutral (Prob: 1.07 %)
#
# Audio File:  ./CREMA_D/happy/1073_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 81.65 %) 	| Top 2: disgust (Prob: 15.92 %) 	| Top 3: fear (Prob: 1.56 %)
#
# Audio File:  ./CREMA_D/happy/1002_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 43.89 %) 	| Top 2: ps (Prob: 37.61 %) 	| Top 3: fear (Prob: 15.46 %)
#
# Audio File:  ./CREMA_D/happy/1001_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 90.92 %) 	| Top 2: angry (Prob: 4.04 %) 	| Top 3: ps (Prob: 2.33 %)
#
# Audio File:  ./CREMA_D/happy/1002_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 21.71 %) 	| Top 2: disgust (Prob: 19.2 %) 	| Top 3: happy (Prob: 19.15 %)
#
# Audio File:  ./CREMA_D/happy/1023_IWW_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 68.04 %) 	| Top 2: disgust (Prob: 17.89 %) 	| Top 3: ps (Prob: 8.5 %)
#
# Audio File:  ./CREMA_D/happy/1014_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 70.53 %) 	| Top 2: disgust (Prob: 16.99 %) 	| Top 3: neutral (Prob: 5.6 %)
#
# Audio File:  ./CREMA_D/happy/1046_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 73.74 %) 	| Top 2: ps (Prob: 18.13 %) 	| Top 3: fear (Prob: 6.24 %)
#
# Audio File:  ./CREMA_D/happy/1036_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 72.98 %) 	| Top 2: disgust (Prob: 20.9 %) 	| Top 3: sad (Prob: 2.73 %)
#
# Audio File:  ./CREMA_D/happy/1057_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 49.73 %) 	| Top 2: ps (Prob: 47.41 %) 	| Top 3: sad (Prob: 1.73 %)
#
# Audio File:  ./CREMA_D/happy/1016_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 69.31 %) 	| Top 2: disgust (Prob: 10.91 %) 	| Top 3: neutral (Prob: 7.4 %)
#
# Audio File:  ./CREMA_D/happy/1054_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 38.68 %) 	| Top 2: ps (Prob: 32.81 %) 	| Top 3: happy (Prob: 12.36 %)
#
# Audio File:  ./CREMA_D/happy/1070_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 90.93 %) 	| Top 2: ps (Prob: 3.17 %) 	| Top 3: neutral (Prob: 2.55 %)
#
# Audio File:  ./CREMA_D/happy/1051_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 95.88 %) 	| Top 2: ps (Prob: 3.71 %) 	| Top 3: sad (Prob: 0.33 %)
#
# Audio File:  ./CREMA_D/happy/1071_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 63.45 %) 	| Top 2: disgust (Prob: 20.29 %) 	| Top 3: fear (Prob: 5.21 %)
#
# Audio File:  ./CREMA_D/happy/1005_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 71.56 %) 	| Top 2: ps (Prob: 22.29 %) 	| Top 3: sad (Prob: 2.42 %)
#
# Audio File:  ./CREMA_D/happy/1036_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 56.55 %) 	| Top 2: ps (Prob: 41.76 %) 	| Top 3: fear (Prob: 1.16 %)
#
# Audio File:  ./CREMA_D/happy/1040_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 65.95 %) 	| Top 2: disgust (Prob: 27.96 %) 	| Top 3: sad (Prob: 4.77 %)
#
# Audio File:  ./CREMA_D/happy/1025_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 87.75 %) 	| Top 2: ps (Prob: 10.26 %) 	| Top 3: neutral (Prob: 1.57 %)
#
# Audio File:  ./CREMA_D/happy/1004_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 87.76 %) 	| Top 2: ps (Prob: 11.44 %) 	| Top 3: sad (Prob: 0.75 %)
#
# Audio File:  ./CREMA_D/happy/1077_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.74 %) 	| Top 2: ps (Prob: 27.16 %) 	| Top 3: neutral (Prob: 6.78 %)
#
# Audio File:  ./CREMA_D/happy/1048_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 66.49 %) 	| Top 2: ps (Prob: 15.13 %) 	| Top 3: neutral (Prob: 9.48 %)
#
# Audio File:  ./CREMA_D/happy/1078_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 95.91 %) 	| Top 2: angry (Prob: 1.64 %) 	| Top 3: fear (Prob: 1.41 %)
#
# Audio File:  ./CREMA_D/happy/1051_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 44.65 %) 	| Top 2: disgust (Prob: 42.38 %) 	| Top 3: fear (Prob: 10.18 %)
#
# Audio File:  ./CREMA_D/happy/1025_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 65.28 %) 	| Top 2: fear (Prob: 16.22 %) 	| Top 3: ps (Prob: 12.92 %)
#
# Audio File:  ./CREMA_D/happy/1057_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 60.09 %) 	| Top 2: disgust (Prob: 35.36 %) 	| Top 3: angry (Prob: 2.02 %)
#
# Audio File:  ./CREMA_D/happy/1074_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 75.86 %) 	| Top 2: ps (Prob: 16.94 %) 	| Top 3: fear (Prob: 5.73 %)
#
# Audio File:  ./CREMA_D/happy/1070_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 85.62 %) 	| Top 2: ps (Prob: 8.01 %) 	| Top 3: sad (Prob: 4.44 %)
#
# Audio File:  ./CREMA_D/happy/1015_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 74.03 %) 	| Top 2: angry (Prob: 16.8 %) 	| Top 3: ps (Prob: 4.04 %)
#
# Audio File:  ./CREMA_D/happy/1002_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 46.36 %) 	| Top 2: disgust (Prob: 44.0 %) 	| Top 3: fear (Prob: 6.5 %)
#
# Audio File:  ./CREMA_D/happy/1048_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 80.48 %) 	| Top 2: ps (Prob: 13.3 %) 	| Top 3: sad (Prob: 5.92 %)
#
# Audio File:  ./CREMA_D/happy/1012_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 95.08 %) 	| Top 2: ps (Prob: 3.79 %) 	| Top 3: sad (Prob: 0.73 %)
#
# Audio File:  ./CREMA_D/happy/1072_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 85.63 %) 	| Top 2: neutral (Prob: 6.86 %) 	| Top 3: disgust (Prob: 6.68 %)
#
# Audio File:  ./CREMA_D/happy/1074_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 73.58 %) 	| Top 2: disgust (Prob: 12.21 %) 	| Top 3: fear (Prob: 12.18 %)
#
# Audio File:  ./CREMA_D/happy/1020_TAI_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 49.08 %) 	| Top 2: ps (Prob: 26.18 %) 	| Top 3: disgust (Prob: 15.92 %)
#
# Audio File:  ./CREMA_D/happy/1039_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 77.22 %) 	| Top 2: ps (Prob: 18.39 %) 	| Top 3: fear (Prob: 2.04 %)
#
# Audio File:  ./CREMA_D/happy/1033_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 87.23 %) 	| Top 2: ps (Prob: 11.51 %) 	| Top 3: sad (Prob: 1.13 %)
#
# Audio File:  ./CREMA_D/happy/1068_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 49.36 %) 	| Top 2: disgust (Prob: 48.09 %) 	| Top 3: sad (Prob: 1.92 %)
#
# Audio File:  ./CREMA_D/happy/1038_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 62.94 %) 	| Top 2: fear (Prob: 26.24 %) 	| Top 3: disgust (Prob: 10.09 %)
#
# Audio File:  ./CREMA_D/happy/1027_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 82.49 %) 	| Top 2: ps (Prob: 11.33 %) 	| Top 3: sad (Prob: 2.03 %)
#
# Audio File:  ./CREMA_D/happy/1012_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 63.53 %) 	| Top 2: ps (Prob: 15.02 %) 	| Top 3: fear (Prob: 10.66 %)
#
# Audio File:  ./CREMA_D/happy/1031_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 55.05 %) 	| Top 2: ps (Prob: 33.92 %) 	| Top 3: neutral (Prob: 5.47 %)
#
# Audio File:  ./CREMA_D/happy/1027_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 79.54 %) 	| Top 2: ps (Prob: 16.94 %) 	| Top 3: neutral (Prob: 1.5 %)
#
# Audio File:  ./CREMA_D/happy/1045_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 83.18 %) 	| Top 2: disgust (Prob: 14.53 %) 	| Top 3: neutral (Prob: 1.6 %)
#
# Audio File:  ./CREMA_D/happy/1001_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 46.83 %) 	| Top 2: angry (Prob: 28.68 %) 	| Top 3: ps (Prob: 16.13 %)
#
# Audio File:  ./CREMA_D/happy/1008_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 69.25 %) 	| Top 2: ps (Prob: 29.79 %) 	| Top 3: sad (Prob: 0.85 %)
#
# Audio File:  ./CREMA_D/happy/1068_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 63.9 %) 	| Top 2: disgust (Prob: 31.73 %) 	| Top 3: angry (Prob: 1.94 %)
#
# Audio File:  ./CREMA_D/happy/1039_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 88.0 %) 	| Top 2: disgust (Prob: 11.23 %) 	| Top 3: fear (Prob: 0.7 %)
#
# Audio File:  ./CREMA_D/happy/1043_IEO_HAP_HI.wav
# Predicted Emotions:  fear 	| Ground Truth:  HI
# Top 1: fear (Prob: 48.7 %) 	| Top 2: disgust (Prob: 21.8 %) 	| Top 3: ps (Prob: 14.64 %)
#
# Audio File:  ./CREMA_D/happy/1024_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 80.33 %) 	| Top 2: ps (Prob: 14.75 %) 	| Top 3: fear (Prob: 1.8 %)
#
# Audio File:  ./CREMA_D/happy/1026_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 34.47 %) 	| Top 2: angry (Prob: 27.92 %) 	| Top 3: fear (Prob: 16.48 %)
#
# Audio File:  ./CREMA_D/happy/1030_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 55.52 %) 	| Top 2: ps (Prob: 43.12 %) 	| Top 3: sad (Prob: 1.15 %)
#
# Audio File:  ./CREMA_D/happy/1041_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 74.24 %) 	| Top 2: disgust (Prob: 7.49 %) 	| Top 3: angry (Prob: 6.4 %)
#
# Audio File:  ./CREMA_D/happy/1074_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 63.22 %) 	| Top 2: fear (Prob: 29.53 %) 	| Top 3: ps (Prob: 5.51 %)
#
# Audio File:  ./CREMA_D/happy/1057_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 61.22 %) 	| Top 2: disgust (Prob: 30.25 %) 	| Top 3: fear (Prob: 4.7 %)
#
# Audio File:  ./CREMA_D/happy/1040_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 44.92 %) 	| Top 2: sad (Prob: 36.47 %) 	| Top 3: ps (Prob: 13.08 %)
#
# Audio File:  ./CREMA_D/happy/1020_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 84.82 %) 	| Top 2: neutral (Prob: 7.25 %) 	| Top 3: ps (Prob: 3.07 %)
#
# Audio File:  ./CREMA_D/happy/1058_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 63.74 %) 	| Top 2: disgust (Prob: 34.67 %) 	| Top 3: fear (Prob: 0.69 %)
#
# Audio File:  ./CREMA_D/happy/1060_TSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 49.14 %) 	| Top 2: ps (Prob: 29.03 %) 	| Top 3: fear (Prob: 15.42 %)
#
# Audio File:  ./CREMA_D/happy/1055_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 61.99 %) 	| Top 2: ps (Prob: 37.33 %) 	| Top 3: sad (Prob: 0.44 %)
#
# Audio File:  ./CREMA_D/happy/1057_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 57.86 %) 	| Top 2: angry (Prob: 11.53 %) 	| Top 3: sad (Prob: 10.02 %)
#
# Audio File:  ./CREMA_D/happy/1026_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 53.97 %) 	| Top 2: disgust (Prob: 43.79 %) 	| Top 3: sad (Prob: 1.57 %)
#
# Audio File:  ./CREMA_D/happy/1040_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 50.06 %) 	| Top 2: ps (Prob: 43.55 %) 	| Top 3: sad (Prob: 3.83 %)
#
# Audio File:  ./CREMA_D/happy/1018_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 75.45 %) 	| Top 2: disgust (Prob: 24.06 %) 	| Top 3: sad (Prob: 0.18 %)
#
# Audio File:  ./CREMA_D/happy/1025_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.08 %) 	| Top 2: ps (Prob: 7.55 %) 	| Top 3: sad (Prob: 0.31 %)
#
# Audio File:  ./CREMA_D/happy/1035_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 89.35 %) 	| Top 2: ps (Prob: 4.37 %) 	| Top 3: sad (Prob: 3.79 %)
#
# Audio File:  ./CREMA_D/happy/1025_IEO_HAP_HI.wav
# Predicted Emotions:  fear 	| Ground Truth:  HI
# Top 1: fear (Prob: 43.58 %) 	| Top 2: disgust (Prob: 41.38 %) 	| Top 3: angry (Prob: 7.53 %)
#
# Audio File:  ./CREMA_D/happy/1014_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 77.48 %) 	| Top 2: fear (Prob: 8.79 %) 	| Top 3: ps (Prob: 7.65 %)
#
# Audio File:  ./CREMA_D/happy/1043_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 77.16 %) 	| Top 2: disgust (Prob: 10.28 %) 	| Top 3: angry (Prob: 6.15 %)
#
# Audio File:  ./CREMA_D/happy/1074_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.02 %) 	| Top 2: ps (Prob: 25.18 %) 	| Top 3: fear (Prob: 18.23 %)
#
# Audio File:  ./CREMA_D/happy/1021_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 50.88 %) 	| Top 2: neutral (Prob: 38.47 %) 	| Top 3: ps (Prob: 6.85 %)
#
# Audio File:  ./CREMA_D/happy/1067_DFA_HAP_XX.wav
# Predicted Emotions:  neutral 	| Ground Truth:  XX
# Top 1: neutral (Prob: 50.9 %) 	| Top 2: disgust (Prob: 27.72 %) 	| Top 3: ps (Prob: 11.46 %)
#
# Audio File:  ./CREMA_D/happy/1003_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 97.87 %) 	| Top 2: ps (Prob: 2.03 %) 	| Top 3: sad (Prob: 0.06 %)
#
# Audio File:  ./CREMA_D/happy/1019_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 36.73 %) 	| Top 2: angry (Prob: 31.57 %) 	| Top 3: ps (Prob: 16.98 %)
#
# Audio File:  ./CREMA_D/happy/1017_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 68.87 %) 	| Top 2: disgust (Prob: 11.96 %) 	| Top 3: angry (Prob: 8.88 %)
#
# Audio File:  ./CREMA_D/happy/1076_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 79.79 %) 	| Top 2: disgust (Prob: 16.94 %) 	| Top 3: fear (Prob: 1.08 %)
#
# Audio File:  ./CREMA_D/happy/1066_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 79.76 %) 	| Top 2: disgust (Prob: 11.44 %) 	| Top 3: angry (Prob: 3.38 %)
#
# Audio File:  ./CREMA_D/happy/1017_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 48.16 %) 	| Top 2: disgust (Prob: 24.06 %) 	| Top 3: sad (Prob: 19.01 %)
#
# Audio File:  ./CREMA_D/happy/1017_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 38.19 %) 	| Top 2: sad (Prob: 18.96 %) 	| Top 3: angry (Prob: 16.94 %)
#
# Audio File:  ./CREMA_D/happy/1068_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 86.85 %) 	| Top 2: disgust (Prob: 9.51 %) 	| Top 3: angry (Prob: 1.26 %)
#
# Audio File:  ./CREMA_D/happy/1071_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 91.55 %) 	| Top 2: disgust (Prob: 5.38 %) 	| Top 3: neutral (Prob: 1.03 %)
#
# Audio File:  ./CREMA_D/happy/1038_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 86.84 %) 	| Top 2: disgust (Prob: 12.19 %) 	| Top 3: fear (Prob: 0.39 %)
#
# Audio File:  ./CREMA_D/happy/1069_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 92.46 %) 	| Top 2: disgust (Prob: 3.1 %) 	| Top 3: angry (Prob: 2.29 %)
#
# Audio File:  ./CREMA_D/happy/1060_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 72.71 %) 	| Top 2: disgust (Prob: 23.98 %) 	| Top 3: sad (Prob: 1.03 %)
#
# Audio File:  ./CREMA_D/happy/1002_TIE_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 87.33 %) 	| Top 2: disgust (Prob: 9.7 %) 	| Top 3: fear (Prob: 2.58 %)
#
# Audio File:  ./CREMA_D/happy/1010_IEO_HAP_HI.wav
# Predicted Emotions:  fear 	| Ground Truth:  HI
# Top 1: fear (Prob: 53.45 %) 	| Top 2: ps (Prob: 25.23 %) 	| Top 3: disgust (Prob: 16.7 %)
#
# Audio File:  ./CREMA_D/happy/1068_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 49.41 %) 	| Top 2: ps (Prob: 48.48 %) 	| Top 3: sad (Prob: 1.81 %)
#
# Audio File:  ./CREMA_D/happy/1068_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 48.78 %) 	| Top 2: disgust (Prob: 24.45 %) 	| Top 3: angry (Prob: 13.87 %)
#
# Audio File:  ./CREMA_D/happy/1065_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 27.85 %) 	| Top 2: disgust (Prob: 27.02 %) 	| Top 3: sad (Prob: 16.82 %)
#
# Audio File:  ./CREMA_D/happy/1010_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 59.08 %) 	| Top 2: fear (Prob: 24.63 %) 	| Top 3: disgust (Prob: 13.24 %)
#
# Audio File:  ./CREMA_D/happy/1048_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 86.49 %) 	| Top 2: happy (Prob: 6.81 %) 	| Top 3: disgust (Prob: 3.04 %)
#
# Audio File:  ./CREMA_D/happy/1072_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 75.76 %) 	| Top 2: disgust (Prob: 23.38 %) 	| Top 3: fear (Prob: 0.33 %)
#
# Audio File:  ./CREMA_D/happy/1017_ITH_HAP_XX.wav
# Predicted Emotions:  angry 	| Ground Truth:  XX
# Top 1: angry (Prob: 45.87 %) 	| Top 2: disgust (Prob: 21.82 %) 	| Top 3: ps (Prob: 12.01 %)
#
# Audio File:  ./CREMA_D/happy/1059_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 67.6 %) 	| Top 2: fear (Prob: 22.69 %) 	| Top 3: disgust (Prob: 7.46 %)
#
# Audio File:  ./CREMA_D/happy/1018_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 47.74 %) 	| Top 2: disgust (Prob: 22.24 %) 	| Top 3: happy (Prob: 21.25 %)
#
# Audio File:  ./CREMA_D/happy/1061_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 96.63 %) 	| Top 2: ps (Prob: 2.63 %) 	| Top 3: sad (Prob: 0.7 %)
#
# Audio File:  ./CREMA_D/happy/1022_IEO_HAP_LO.wav
# Predicted Emotions:  ps 	| Ground Truth:  LO
# Top 1: ps (Prob: 59.89 %) 	| Top 2: sad (Prob: 10.03 %) 	| Top 3: angry (Prob: 9.13 %)
#
# Audio File:  ./CREMA_D/happy/1032_ITH_HAP_XX.wav
# Predicted Emotions:  sad 	| Ground Truth:  XX
# Top 1: sad (Prob: 78.16 %) 	| Top 2: ps (Prob: 14.29 %) 	| Top 3: disgust (Prob: 4.1 %)
#
# ...
#
# Audio File:  ./CREMA_D/happy/1044_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 59.15 %) 	| Top 2: ps (Prob: 38.72 %) 	| Top 3: sad (Prob: 1.49 %)
#
# Audio File:  ./CREMA_D/happy/1066_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 84.68 %) 	| Top 2: happy (Prob: 4.45 %) 	| Top 3: disgust (Prob: 3.55 %)
#
# Audio File:  ./CREMA_D/happy/1006_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 95.33 %) 	| Top 2: fear (Prob: 3.0 %) 	| Top 3: disgust (Prob: 1.17 %)
#
# Audio File:  ./CREMA_D/happy/1050_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 46.65 %) 	| Top 2: disgust (Prob: 26.68 %) 	| Top 3: angry (Prob: 6.49 %)
#
# Audio File:  ./CREMA_D/happy/1065_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 90.47 %) 	| Top 2: disgust (Prob: 6.46 %) 	| Top 3: neutral (Prob: 2.33 %)
#
# Audio File:  ./CREMA_D/happy/1041_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 82.3 %) 	| Top 2: disgust (Prob: 11.12 %) 	| Top 3: angry (Prob: 3.96 %)
#
# Audio File:  ./CREMA_D/happy/1046_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 36.7 %) 	| Top 2: disgust (Prob: 31.89 %) 	| Top 3: fear (Prob: 20.56 %)
#
# Audio File:  ./CREMA_D/happy/1011_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 53.81 %) 	| Top 2: neutral (Prob: 26.98 %) 	| Top 3: ps (Prob: 13.85 %)
#
# Audio File:  ./CREMA_D/happy/1028_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 93.69 %) 	| Top 2: fear (Prob: 2.91 %) 	| Top 3: disgust (Prob: 1.92 %)
#
# Audio File:  ./CREMA_D/happy/1030_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.69 %) 	| Top 2: ps (Prob: 19.41 %) 	| Top 3: fear (Prob: 3.95 %)
#
# Audio File:  ./CREMA_D/happy/1006_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 64.27 %) 	| Top 2: sad (Prob: 16.37 %) 	| Top 3: ps (Prob: 9.35 %)
#
# Audio File:  ./CREMA_D/happy/1031_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 60.88 %) 	| Top 2: disgust (Prob: 29.49 %) 	| Top 3: neutral (Prob: 7.77 %)
#
# Audio File:  ./CREMA_D/happy/1051_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 76.42 %) 	| Top 2: disgust (Prob: 21.69 %) 	| Top 3: angry (Prob: 0.57 %)
#
# Audio File:  ./CREMA_D/happy/1046_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 37.73 %) 	| Top 2: neutral (Prob: 21.41 %) 	| Top 3: ps (Prob: 18.0 %)
#
# Audio File:  ./CREMA_D/happy/1023_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 72.86 %) 	| Top 2: disgust (Prob: 17.07 %) 	| Top 3: neutral (Prob: 4.82 %)
#
# Audio File:  ./CREMA_D/happy/1001_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 94.88 %) 	| Top 2: disgust (Prob: 3.45 %) 	| Top 3: neutral (Prob: 0.61 %)
#
# Audio File:  ./CREMA_D/happy/1067_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 90.74 %) 	| Top 2: ps (Prob: 6.41 %) 	| Top 3: sad (Prob: 1.75 %)
#
# Audio File:  ./CREMA_D/happy/1049_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 62.42 %) 	| Top 2: disgust (Prob: 15.85 %) 	| Top 3: fear (Prob: 15.55 %)
#
# Audio File:  ./CREMA_D/happy/1050_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 81.46 %) 	| Top 2: ps (Prob: 16.3 %) 	| Top 3: sad (Prob: 1.15 %)
#
# Audio File:  ./CREMA_D/happy/1042_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 87.75 %) 	| Top 2: happy (Prob: 3.39 %) 	| Top 3: disgust (Prob: 3.0 %)
#
# Audio File:  ./CREMA_D/happy/1025_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 93.06 %) 	| Top 2: ps (Prob: 3.55 %) 	| Top 3: sad (Prob: 3.0 %)
#
# Audio File:  ./CREMA_D/happy/1032_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 84.34 %) 	| Top 2: ps (Prob: 6.79 %) 	| Top 3: sad (Prob: 5.61 %)
#
# Audio File:  ./CREMA_D/happy/1001_IEO_HAP_HI.wav
# Predicted Emotions:  angry 	| Ground Truth:  HI
# Top 1: angry (Prob: 53.83 %) 	| Top 2: ps (Prob: 34.53 %) 	| Top 3: disgust (Prob: 9.85 %)
#
# Audio File:  ./CREMA_D/happy/1069_TAI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 45.34 %) 	| Top 2: angry (Prob: 29.52 %) 	| Top 3: disgust (Prob: 12.88 %)
#
# Audio File:  ./CREMA_D/happy/1039_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 46.71 %) 	| Top 2: disgust (Prob: 40.36 %) 	| Top 3: fear (Prob: 6.67 %)
#
# Audio File:  ./CREMA_D/happy/1003_IEO_HAP_HI.wav
# Predicted Emotions:  disgust 	| Ground Truth:  HI
# Top 1: disgust (Prob: 65.64 %) 	| Top 2: angry (Prob: 14.82 %) 	| Top 3: ps (Prob: 12.5 %)
#
# Audio File:  ./CREMA_D/happy/1045_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.34 %) 	| Top 2: ps (Prob: 19.87 %) 	| Top 3: sad (Prob: 3.74 %)
#
# Audio File:  ./CREMA_D/happy/1004_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 60.52 %) 	| Top 2: ps (Prob: 35.95 %) 	| Top 3: sad (Prob: 1.8 %)
#
# Audio File:  ./CREMA_D/happy/1016_IOM_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 87.09 %) 	| Top 2: disgust (Prob: 11.72 %) 	| Top 3: neutral (Prob: 0.4 %)
#
# Audio File:  ./CREMA_D/happy/1012_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 58.3 %) 	| Top 2: ps (Prob: 32.78 %) 	| Top 3: fear (Prob: 4.88 %)
#
# Audio File:  ./CREMA_D/happy/1061_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 79.51 %) 	| Top 2: ps (Prob: 18.37 %) 	| Top 3: fear (Prob: 1.17 %)
#
# Audio File:  ./CREMA_D/happy/1031_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 79.64 %) 	| Top 2: ps (Prob: 14.2 %) 	| Top 3: neutral (Prob: 3.37 %)
#
# Audio File:  ./CREMA_D/happy/1052_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 59.86 %) 	| Top 2: disgust (Prob: 35.5 %) 	| Top 3: sad (Prob: 2.34 %)
#
# Audio File:  ./CREMA_D/happy/1056_ITH_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 71.45 %) 	| Top 2: disgust (Prob: 27.37 %) 	| Top 3: sad (Prob: 0.73 %)
#
# Audio File:  ./CREMA_D/happy/1009_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 54.76 %) 	| Top 2: disgust (Prob: 21.01 %) 	| Top 3: fear (Prob: 12.26 %)
#
# Audio File:  ./CREMA_D/happy/1021_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 78.03 %) 	| Top 2: sad (Prob: 18.67 %) 	| Top 3: ps (Prob: 3.25 %)
#
# Audio File:  ./CREMA_D/happy/1021_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 77.41 %) 	| Top 2: ps (Prob: 19.66 %) 	| Top 3: sad (Prob: 2.69 %)
#
# Audio File:  ./CREMA_D/happy/1022_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 59.71 %) 	| Top 2: sad (Prob: 13.79 %) 	| Top 3: happy (Prob: 9.32 %)
#
# Audio File:  ./CREMA_D/happy/1004_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 73.46 %) 	| Top 2: ps (Prob: 26.47 %) 	| Top 3: fear (Prob: 0.03 %)
#
# Audio File:  ./CREMA_D/happy/1075_IWW_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 56.53 %) 	| Top 2: ps (Prob: 25.76 %) 	| Top 3: sad (Prob: 7.99 %)
#
# Audio File:  ./CREMA_D/happy/1016_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 56.26 %) 	| Top 2: angry (Prob: 13.2 %) 	| Top 3: disgust (Prob: 10.39 %)
#
# Audio File:  ./CREMA_D/happy/1027_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 71.23 %) 	| Top 2: sad (Prob: 28.76 %) 	| Top 3: ps (Prob: 0.01 %)
#
# Audio File:  ./CREMA_D/happy/1006_IEO_HAP_MD.wav
# Predicted Emotions:  disgust 	| Ground Truth:  MD
# Top 1: disgust (Prob: 91.92 %) 	| Top 2: ps (Prob: 4.63 %) 	| Top 3: fear (Prob: 1.75 %)
#
# Audio File:  ./CREMA_D/happy/1051_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 57.29 %) 	| Top 2: ps (Prob: 32.32 %) 	| Top 3: angry (Prob: 5.14 %)
#
# Audio File:  ./CREMA_D/happy/1015_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 98.18 %) 	| Top 2: fear (Prob: 1.11 %) 	| Top 3: angry (Prob: 0.46 %)
#
# Audio File:  ./CREMA_D/happy/1013_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 94.46 %) 	| Top 2: disgust (Prob: 4.78 %) 	| Top 3: fear (Prob: 0.4 %)
#
# Audio File:  ./CREMA_D/happy/1021_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 89.41 %) 	| Top 2: sad (Prob: 5.15 %) 	| Top 3: ps (Prob: 4.32 %)
#
# Audio File:  ./CREMA_D/happy/1011_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 43.27 %) 	| Top 2: disgust (Prob: 43.03 %) 	| Top 3: sad (Prob: 7.17 %)
#
# Audio File:  ./CREMA_D/happy/1071_MTI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 38.8 %) 	| Top 2: disgust (Prob: 30.17 %) 	| Top 3: angry (Prob: 14.15 %)
#
# Audio File:  ./CREMA_D/happy/1041_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 64.71 %) 	| Top 2: sad (Prob: 14.11 %) 	| Top 3: disgust (Prob: 6.6 %)
#
# Audio File:  ./CREMA_D/happy/1008_DFA_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 99.98 %) 	| Top 2: ps (Prob: 0.02 %) 	| Top 3: sad (Prob: 0.0 %)
#
# Audio File:  ./CREMA_D/happy/1001_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 86.24 %) 	| Top 2: fear (Prob: 3.82 %) 	| Top 3: neutral (Prob: 3.53 %)
#
# Audio File:  ./CREMA_D/happy/1022_WSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 76.56 %) 	| Top 2: ps (Prob: 21.51 %) 	| Top 3: sad (Prob: 1.79 %)
#
# Audio File:  ./CREMA_D/happy/1036_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 36.11 %) 	| Top 2: sad (Prob: 22.61 %) 	| Top 3: angry (Prob: 13.8 %)
#
# Audio File:  ./CREMA_D/happy/1058_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 73.93 %) 	| Top 2: ps (Prob: 25.19 %) 	| Top 3: sad (Prob: 0.8 %)
#
# Audio File:  ./CREMA_D/happy/1012_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 71.71 %) 	| Top 2: ps (Prob: 22.55 %) 	| Top 3: sad (Prob: 4.98 %)
#
# Audio File:  ./CREMA_D/happy/1020_ITS_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 61.49 %) 	| Top 2: sad (Prob: 20.03 %) 	| Top 3: happy (Prob: 15.45 %)
#
# Audio File:  ./CREMA_D/happy/1020_TSI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 70.96 %) 	| Top 2: ps (Prob: 16.0 %) 	| Top 3: sad (Prob: 7.88 %)
#
# Audio File:  ./CREMA_D/happy/1066_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 90.46 %) 	| Top 2: angry (Prob: 2.57 %) 	| Top 3: disgust (Prob: 2.39 %)
#
# Audio File:  ./CREMA_D/happy/1010_DFA_HAP_XX.wav
# Predicted Emotions:  fear 	| Ground Truth:  XX
# Top 1: fear (Prob: 47.65 %) 	| Top 2: ps (Prob: 23.24 %) 	| Top 3: disgust (Prob: 20.96 %)
#
# Audio File:  ./CREMA_D/happy/1012_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.04 %) 	| Top 2: ps (Prob: 7.61 %) 	| Top 3: sad (Prob: 0.32 %)
#
# Audio File:  ./CREMA_D/happy/1009_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 84.14 %) 	| Top 2: disgust (Prob: 5.46 %) 	| Top 3: sad (Prob: 3.95 %)
#
# Audio File:  ./CREMA_D/happy/1030_IEO_HAP_LO.wav
# Predicted Emotions:  angry 	| Ground Truth:  LO
# Top 1: angry (Prob: 28.06 %) 	| Top 2: ps (Prob: 24.44 %) 	| Top 3: disgust (Prob: 19.6 %)
#
# Audio File:  ./CREMA_D/happy/1014_TSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 81.38 %) 	| Top 2: disgust (Prob: 17.93 %) 	| Top 3: sad (Prob: 0.34 %)
#
# Audio File:  ./CREMA_D/happy/1045_IEO_HAP_LO.wav
# Predicted Emotions:  angry 	| Ground Truth:  LO
# Top 1: angry (Prob: 35.18 %) 	| Top 2: ps (Prob: 34.27 %) 	| Top 3: disgust (Prob: 20.8 %)
#
# Audio File:  ./CREMA_D/happy/1012_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.24 %) 	| Top 2: ps (Prob: 19.0 %) 	| Top 3: fear (Prob: 3.38 %)
#
# Audio File:  ./CREMA_D/happy/1041_IEO_HAP_LO.wav
# Predicted Emotions:  disgust 	| Ground Truth:  LO
# Top 1: disgust (Prob: 36.98 %) 	| Top 2: ps (Prob: 32.01 %) 	| Top 3: neutral (Prob: 19.6 %)
#
# Audio File:  ./CREMA_D/happy/1061_TAI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.28 %) 	| Top 2: ps (Prob: 6.28 %) 	| Top 3: neutral (Prob: 0.73 %)
#
# Audio File:  ./CREMA_D/happy/1075_IEO_HAP_LO.wav
# Predicted Emotions:  angry 	| Ground Truth:  LO
# Top 1: angry (Prob: 51.52 %) 	| Top 2: disgust (Prob: 21.2 %) 	| Top 3: ps (Prob: 16.84 %)
#
# Audio File:  ./CREMA_D/happy/1006_ITS_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 64.59 %) 	| Top 2: ps (Prob: 34.79 %) 	| Top 3: sad (Prob: 0.39 %)
#
# Audio File:  ./CREMA_D/happy/1073_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 72.39 %) 	| Top 2: ps (Prob: 26.32 %) 	| Top 3: sad (Prob: 0.6 %)
#
# Audio File:  ./CREMA_D/happy/1013_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 57.32 %) 	| Top 2: disgust (Prob: 14.48 %) 	| Top 3: angry (Prob: 9.83 %)
#
# Audio File:  ./CREMA_D/happy/1073_ITH_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 92.13 %) 	| Top 2: ps (Prob: 7.11 %) 	| Top 3: sad (Prob: 0.65 %)
#
# Audio File:  ./CREMA_D/happy/1040_IEO_HAP_HI.wav
# Predicted Emotions:  ps 	| Ground Truth:  HI
# Top 1: ps (Prob: 79.48 %) 	| Top 2: disgust (Prob: 19.51 %) 	| Top 3: angry (Prob: 0.31 %)
#
# Audio File:  ./CREMA_D/happy/1060_IWL_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 93.31 %) 	| Top 2: ps (Prob: 3.74 %) 	| Top 3: fear (Prob: 2.68 %)
#
# Audio File:  ./CREMA_D/happy/1024_IOM_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 38.04 %) 	| Top 2: neutral (Prob: 14.5 %) 	| Top 3: sad (Prob: 14.35 %)
#
# Audio File:  ./CREMA_D/happy/1071_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 71.34 %) 	| Top 2: disgust (Prob: 18.09 %) 	| Top 3: neutral (Prob: 5.64 %)
#
# Audio File:  ./CREMA_D/happy/1078_IWL_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 95.89 %) 	| Top 2: disgust (Prob: 2.22 %) 	| Top 3: fear (Prob: 1.81 %)
#
# Audio File:  ./CREMA_D/happy/1033_WSI_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 97.4 %) 	| Top 2: disgust (Prob: 1.97 %) 	| Top 3: fear (Prob: 0.29 %)
#
# Audio File:  ./CREMA_D/happy/1002_IEO_HAP_MD.wav
# Predicted Emotions:  ps 	| Ground Truth:  MD
# Top 1: ps (Prob: 53.84 %) 	| Top 2: disgust (Prob: 38.33 %) 	| Top 3: neutral (Prob: 2.89 %)
#
# Audio File:  ./CREMA_D/happy/1066_IWW_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 75.78 %) 	| Top 2: disgust (Prob: 9.54 %) 	| Top 3: happy (Prob: 4.34 %)
#
# Audio File:  ./CREMA_D/happy/1047_MTI_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 83.82 %) 	| Top 2: ps (Prob: 14.53 %) 	| Top 3: sad (Prob: 1.6 %)
#
# Audio File:  ./CREMA_D/happy/1076_DFA_HAP_XX.wav
# Predicted Emotions:  ps 	| Ground Truth:  XX
# Top 1: ps (Prob: 72.39 %) 	| Top 2: disgust (Prob: 26.57 %) 	| Top 3: sad (Prob: 0.34 %)
#
# Audio File:  ./CREMA_D/happy/1008_TIE_HAP_XX.wav
# Predicted Emotions:  disgust 	| Ground Truth:  XX
# Top 1: disgust (Prob: 98.81 %) 	| Top 2: ps (Prob: 0.96 %) 	| Top 3: sad (Prob: 0.22 %)
#
# Audio File:  ./CREMA_D/happy/1057_IEO_HAP_LO.wav
# Predicted Emotions:  neutral 	| Ground Truth:  LO
# Top 1: neutral (Prob: 59.52 %) 	| Top 2: disgust (Prob: 18.44 %) 	| Top 3: ps (Prob: 13.34 %)
